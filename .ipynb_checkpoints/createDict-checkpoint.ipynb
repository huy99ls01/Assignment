# %%
import io

# %%
fileName = "/Users/bangdo/Documents/STUDY/OOP/Dictionary/dictionary.txt"

# %%
with open(fileName, "r") as file:
    i = 0
    #print(type(file))
    check = False
    for line in file:
        if (line[0] == "@"):
            j = 0
            for j in range(int(len(line))):
                #print(line[i])
                check = True
                if (line[j] == '/'):
                    line = line[1:j-1]
                    f = open("dict.txt", "a")
                    f.write(line + "\t")
                    break
        elif (line[0] == "-" and check == True):
            check = False
            l = 0
            f = open("dict.txt", "a")
            f.write(line[2:] )
            #f.write(line[2:l] + "\n")
            """
            pos1 = line.find("(")
            if (pos != -1):
                pos2 = line.find(")")
                line = line[:pos1 -1] + line[pos2 + 1:]
                
            #leng = int(len(line))
            for l in range(int(len(line))):
                if (line[l] == "," or line[l] == ";" or line[l] == "\n"):
                    f = open("dict.txt", "a")
                    f.write(line[2:l] + "\n")
                    break
            """
            #print("OK")
        if (line == "(Tech) quan hệ 1 đối nhiều\n"):
            break
        i = i + 1

# %%
fileName2 = "dict.txt"

# %%
with open(fileName2, "r") as file:
    for line in file:
        pos1 = line.find("(")
        if (pos1 != -1):
            pos2 = line.find(")")
            print(line[pos1:pos2])
            line = line[:pos1 - 1] + line[pos2 + 1:]
            
        f = open("dict2.txt", "a")
        f.write(line)
# Out:
# (c) loại a
# (ỹ) nhiều, dồi
# (m)
# (c) chó sói đ
# (c) con kên k
# (p)
#
# (i) ở phí
# (ỹ) bào ngư
#
# (h) (nhiếp
# (ý) ngườ
# (a) dướ
# (ự) đống
# (ự) có đ
# (t) sợi can
# (c) tr
# (.)
#
# (.)
#
# (.)
#
# (c) bụ
# (u) rẽ ra,
# (.)
#
# (.), sự bắ
# (i),  (hà
# (c) cây bạch
# (c) cây vông
# (c) khôn
# (c) Abie
# (m) (như) habiliate
# (ì)
#
# (c) sự phát s
# (c) phát sinh
# (c) phát sinh
# (c) phát sinh
# (c) sự phát s
# (c) cắ
# (c) sự
# (c) (thuộc) c
# (c) Aplau
#
# (ự)
#
# (c) cá aplet,
# (c) cá aplet,
# (t) có
# (t) có
# (a)
# (o) lễ rử
# (ì)
#
# (.); sự
# (ỹ) làm cho the
# (c) chủ
# (ỹ) làm cho the
# (c) th
# (n) & (nghĩ
# (i)
#
# (c) ch
# (h) có rất n
# (ự) sự q
# (t) búa t
# (a)
# (c) không man
# (c) không man
# (a)
# (a)
# (.)
#
# (c) áp
# (c) độ ho
# (ư)
# (ư)
# (ư)
# (c) sự
# (c),
# (.)
#
# (c) ap
# (ý) sự t
# (ị) sự chu
# (ị) người
# (c)
#
# (c) là
# (t) thiết
# (m) sự
# (.)
#
# (t) chủ ngh
# (t) người t
# (c) ch
# (n) giáp giớ
# (c) giống cây
# (ý) chủ
# (a) (nh
# (c) giống cây
# (a) học
# (c) họ
# (c) họ
# (h)
#
# (c) cái ghẻ
#
# (c) không lá
# (c) không sin
# (c) cái ghẻ
#
# (c) không thâ
# (c) không thâ
# (c) không thâ
# (c) không thâ
# (c) chim chíc
# (c) tr
# (ữ)
#
# (p) người nhận
# (c) hình thái
# (c) ch
# (i)
#
# (i)
#
# (i)
#
# (c)
#
# (ỹ) xe lửa địa
# (c) ngườ
# (i)
#
# (g) + wi
# (o) t
# (c) đàn
# (h)
#
# (.); trang bị cho
#
# (.)
#
# (i); đ
# (c) cùng phát
# (o) đ
# (c) (thuộc) đ
# (i) quân
# (n)
#
# (c) hình kim
# (c) hình kim
# (c) mọc thành
# (c) Axet
# (c) axet
# (c) Axet
# (c) quả bế
#
# (p)
#
# (n)
#
# (c) không bao
# (ý) tiê
# (ý) tín
# (ý) làm
# (ý) làm
# (c) Axit
# (c) sự a
# (c) chất
# (c) sự
# (c) (như)
# (ý) khô
# (ũ)
# (o) thầy
# (c) cây phụ t
# (c) quả đầu
#
# (c) cây không
# (c) không lá
# (c) âm
# (g) + wi
# (n)
#
# (a)
#
# (h)
#
# (ộ)
#
# (c) có quả ở
# (c) sinh ở ng
# (c) bệ
# (c) xuất hiện
# (c) xuất hiện
# (g) chữ đầu (
# (c) ch
# (p)
#
# (c) bào tử ng
# (a) chữ
# (c) hải quỳ
#
# (c) hải quỳ
#
# (ý),  (
# (ý),  (
# (c) Acti
# (ý) cái
# (c) đối xứng
# (c) đối xứng
# (c); (si
# (.); kép, kép hát
#
# (.)
#
# (.)
#
# (.); tính s
# (c) có gai
#
# (c) nhọn mũi
#
# (c) th
# (c) (viết
# (t) a i) q
# (c) ứng kh
# (c) khoa
# (i)
#
# (.)
#
# (g) + up
# (c) linh dươn
# (h); vật thêm vào,
# (h); vật thêm vào,
# (c) cây lưỡi
# (c) cây lưỡi
# (c) bệ
# (c) tính
# (.)
#
# (.)
#
# (.)
#
# (u) khép (
# (.)
#
# (u) khép (
# (u) sự khé
# (u) cơ khé
# (c) vi
# (c) bệ
# (ì)
#
# (n)
# (ý) đoạ
# (c) cây đuôi
# (t)
#
# (c) ch
# (c) có tính c
# (à)
#
# (ỹ) trợ giáo
#
# (c)
#
# (ự) chức
# (ỹ) người chuyê
# (ỹ) trông nom,
# (c) hà
# (h)
# (.); cho hưởng (quyền lợi...
# (o)
#
# (c) hợp sinh
#
# (c) tính từ,
# (g)
#
# (c) A-đô-nít (người
# (g) to
# (ổ); (thơ ca) ở
# (u) trên t
# (c) Ad
# (n) & (nghĩ
# (c) hút
# (c) chất
# (c) hút
# (c) máy
# (c) sự h
# (u)
#
# (.)
#
# (ự) quân
# (g)
#
# (m) (như) adventuro
# (c) phó từ
#
# (c) (thuộc) p
# (c) đối lập
#
# (t); nói đến,
# (.)
#
# (c) ch
# (c) mệ
# (g)
#
# (g)
#
# (h)
#
# (h)
#
# (ý) dị
# (ý) tín
# (i)
#
# (y)
#
# (í)
#
# (y)
#
# (c) bệ
# (ý) môn
# (c) hà
# (c) hà
# (t) khí cầu học
#
# (i)
#
# (c) mỹ
# (c) mù
# (c) ngủ hè
#
# (c) sự ngủ hè
# (s) có ý (tốt,
# (c) hướng vào
# (c) âu y
# (n) sự tin
# (ý) bản
# (t) sự ti
# (ữ)
#
# (i)
#
# (i); sự chả
# (ì)
#
# (g)
#
# (i) sự th
# (c) âm tắc xá
# (a); (t
# (i)
#
# (n) & (ngh
# (n) & (nghĩ
# (c), lơ lửng (
# (i) ở phí
# (i)
#
# (n)
#
# (i)
#
# (i)
#
# (c) ch
# (ẻ)
#
# (g) thùng c
# (ỏ) hơi b
# (n)
#
# (u) ánh s
# (ư)
# (i) ở đuô
# (u) tiết
# (c) món ph
# (t) dư chấn
#
# (i)
#
# (h)
#
# (c) vô tính
#
# (c) vô tính
#
# (c)
#
# (c) nấm tán
#
# (c) thuộc họ
# (c) cây thùa
#
# (u) những
# (c) chất
# (i); nân
# (i); sự
# (m) gây sự, gây hấn
# (g),  d
# (c)
#
# (.)
#
# (t) xi
# (y)
#
# (c) (thuộc
# (c) thuyết
# (c) cu
# (c)
#
# (c) chuột lan
# (c) chuột lan
# (c) ru
# (o) sự chấp
# (c) nô
# (g) sc
# (g) sc
# (p) máy kéo
#
# (c) nô
# (c) nô
# (c) nô
# (ỷ)
#
# (c) bệ
# (c) bệ
# (.)
#
# (i) bớ! ớ
# (i) buồm
# (ỹ) hộ lý
#
# (ự) bệnh
# (ự) sĩ q
# (ự) sĩ q
# (ự) sĩ q
# (.)
#
# (c) cò bạch,
# (c) ((cũng
# (c) cây lá lĩ
# (g) số n
# (ự) thượ
# (ự) thiế
# (ự) khôn
# (t) thang
# (ự) khôn
# (ự) lực
# (ự) thiế
# (m)
#
# (ư)[
# (ự) căn
# (c) bong bóng
# (g) cầu hàn
# (g) lỗ hổng
# (.)
#
# (u) túi ph
# (.)
#
# (ự) sự p
# (t) cái q
# (g) khung m
# (i)
#
# (u)
#
# (t) nút k
# (ự) trun
# (g) lỗ hổng
# (g)
#
# (c) sự
# (y)
#
# (y)
#
# (h)
#
# (ự) đơn
# (ự) lính
# (ỹ) sân bay
#
# (ỹ) máy bay, tà
# (y)
#
# (y)
#
# (g)
#
# (g)
#
# (ò)
# (a)
#
# (a)
#
# (c) quả bế
#
# (t) thạch ca
# (ổ) than ôi!, l
# (ổ) than ôi!, l
# (c) cá
# (ự) nơi
# (a) sự
# (h)
#
# (c) cá ngừ
#
# (c) An
# (ổ) mặc dù, dù,
# (g)[Al
# (c) ch
# (a) nướ
# (t) Fenspat
# (c) ch
# (h)
#
# (c) Anbu
# (c) Anbu
# (c) an
# (c) ch
# (ỗ)
# (c) th
# (c) th
# (m)
#
# (m)
#
# (c) rư
# (ể)
#
# (i)
#
# (.)
#
# (c) Anđe
# (c) cây tổng
# (i) dưới
# (g) li
# (c) hạt alơro
# (c) hạt alơro
# (t)
#
# (c) ch
# (c) cỏ linh l
# (c) tảo
#
# (c) tảo
#
# (c) An
# (c) An
# (ý) chứn
# (c) (thu
# (t) Aliđa
# (t) Aliđa
# (c) nư
# (ý) tính
# (ý) có t
# (ý) ngườ
# (ý) ngườ
# (c) ng
# (c) đồ
# (c) có chân c
# (c) béo
#
# (c) ước s
# (c) Aliz
# (c) Aliz
# (c) độ k
# (c) có đ
# (c) chất
# (c) có t
# (c) kiềm
# (c) cái
# (c) (thu
# (c) phép
# (c) kiềm
# (c) sự k
# (c) kiềm
# (c) Anca
# (o) ngày
# (o) ngày
# (o) toàn diện, gi
# (g)
#
# (ỹ),  (từ lóng)
# (i), tấ
# (o) môn vật tự do
# (c) cảm th
# (g) tổng tr
# (o) thánh
# (ữ)
#
# (n) & (ngh
# (c) hơi
# (c) nhan
# (c) dị
# (c) dị
# (n)
#
# (n)
#
# (à); ngõ hẻm, phố
# (c) (thuộc) l
# (c) lê tàu
#
# (ì)
#
# (ì)
#
# (.)
#
# (n)
#
# (c) sự giao p
# (c) th
# (c) (t
# (c) ph
# (i); định dùng (m
# (c); sự đị
# (c) cây lắm h
# (m)
#
# (c) bồ
# (.)
#
# (o)
#
# (i); sách chiê
# (c) cây hạnh
#
# (ư),
# (g) dùn
# (c) cây lô hộ
# (c) tì
# (i) ở dướ
# (c) Anpaca (đ
# (o) gậy leo núi (
# (ý) tia
# (c) bả
# (c) dã
# (c) ngựa t
# (c) nốt
# (g)
#
# (t) xen kẽ
#
# (i)
#
# (c) máy d
# (g) máy ghi
# (g) so v
# (c) giọn
# (g) mây du
# (t) đắp nổi
# (g) mây tr
# (c) ch
# (c) ph
# (ỹ) (như) alumi
# (n) nữ
# (n) nữ
# (n) học
# (n) học
# (c) tú
# (ộ) vú em, bõ
#
# (ổ),  (thơ ca)
# (c) hỗn
# (c) hỗn
# (c) đã h
# (c) sự h
# (c) máy
# (c) nấm amani
# (t)
#
# (c) đỏ tía
#
# (c) (thuộc) h
# (a)
#
# (ư)
# (ổ)
#
# (c) ch
# (ỹ)
#
# (c) đạ
# (ì); sự
# (ì); có
# (c) ch
# (c) thức ăn của thần
# (ỹ),  (thông tụ
# (c) di
# (c) sự
# (ò)
#
# (ư)
# (ư)
# (o) A-men
# (ỹ) góc ngoan đ
# (c) sự
# (c) sự
# (c) đuôi sóc
# (c) đuôi sóc
# (c) cỏ cụm ho
# (c) mang cụm
# (c) hình đuôi
# (c) đuôi sóc
# (c) Ch
# (c) Amer
# (ỹ)
# (c)
#
# (t) Ametit,
# (c) th
# (c) ch
# (t) Amiăng
#
# (o) khăn
# (n) & (nghĩ
# (c) Amit
# (c) Amiđ
# (c) Amiđ
# (i) ở giữ
# (n) & (nghĩ
# (c) Amin
# (c) cái đ
# (c) (thuộc) h
# (t) của a
# (m)
#
# (c) Amon
# (c) (thu
# (c) (thu
# (c) sự a
# (á)
#
# (c) Amon
# (c) mà
# (c) mà
# (c) am
# (c) am
# (n)
#
# (n)
#
# (n)
#
# (g) là b
# (c) sự đo
# (c) Amper
# (c) Ampe
# (c) Ampe
# (c) cái đ
# (c) lớp lưỡng
# (c) lưỡng cư,
# (c) lưỡng cư,
# (a)
#
# (p)
#
# (c) loài song
# (c) song giao
# (c) sinh ở bê
# (c) con lưỡng
# (c) giáp xác
# (u) (động
# (c) (thuộc) b
# (c) có chân h
# (c) rắn hai đầu
#
# (c)
#
# (c) gi
# (ã)
#
# (c) (t
# (ý); (h
# (c) ôm thân (
# (c) mở rộn
# (ý) Amp
# (u) (cổ La mã)
#
# (i) bình
#
# (u) (cổ La mã)
#
# (ể)
#
# (c) th
# (y)
#
# (c) Amyl
# (c) ti
# (c) Amyl
# (c) Amilopxin
# (ổ); (thông tục
# (c) gi
# (c) cá rô
#
# (g) do luồ
# (c) trạng thá
# (c) (thuộc) s
# (c) sự đồng h
# (g)
#
# (c) quả đào l
# (c) (thuộc) h
# (c) cây đào l
# (p)
#
# (c) kh
# (c) con trăn
# (p)
#
# (a)
#
# (n)
#
# (c) bệ
# (c) th
# (c) gâ
# (c) ng
# (c) ch
# (c) ch
# (c) ph
# (c) ph
# (c) phép đảo
# (c) ph
# (c) ph
# (u) (thuộc
# (c) hồ
# (c) ch
# (c) là
# (c) là
# (ý); (h
# (c) ph
# (a)
#
# (c) quả dứa
#
# (c) không có
# (i)
#
# (c) th
# (ỹ) (như) anapa
# (ỹ) (như) anapa
# (c) pha sau (
# (c) phép
# (c) (thu
# (c) tí
# (c) (t
# (c) th
# (a) thủ
# (p)
#
# (c) ch
# (c) ph
# (.)
#
# (.)
#
# (.)
#
# (.)
#
# (c) phép đảo
#
# (c) kh
# (c) ngược (no
# (ò)
#
# (c) mụ
# (c) ôn
# (i) cái n
# (o) cú đánh lần l
# (c) ng
# (c) cá trống
#
# (c) bệ
# (c) thờ
# (ã)
#
# (ư)
# (u) cùi ta
# (c) cừu ancon
# (c) thon
# (c) hơi
# (y) di đ
# (i)
#
# (c) bộ nhị
#
# (i)
#
# (c) chòm sao t
# (c) ch
# (c) ch
# (c) ch
# (ổ) xức dầu thá
# (g) máy gh
# (c) ph
# (g) cái đo
# (g) phép đ
# (c) cò chân n
# (c) truyền ph
# (ổ), (Ê-cốt) về
# (g) an
# (c) gâ
# (c) cây thì l
# (c) ch
# (c) (t
# (c) ch
# (c) (t
# (ý) quyề
# (c) th
# (c) cây bạch
# (c) th
# (o) kinh
# (c) bệ
# (c) (t
# (c) (t
# (c) u
# (c) cây hạt k
# (c) (thuộc) c
# (t) thép
# (c) gi
# (o) giáo
# (g) an
# (g) an
# (ổ)
#
# (c) rắ
# (n)
#
# (c) gó
# (c) có lá hẹp
# (ổ)
#
# (c) sự
# (c) đo
# (c) Anhy
# (t) thạch ca
# (c) khan
# (g)
#
# (n) đập
# (c) bà
# (c) Anil
# (à)
#
# (g) + on
# (c) vi
# (c) hoạt
# (i)
#
# (c) thuyết
# (c) người
# (c) (thuộc
# (ý) Ani
# (c) cây anit
# (c) có chân k
# (c) khôn
# (c) không cùn
# (ý) khô
# (c) tậ
# (c) không đều
# (c) không đều
# (c) tậ
# (ý) khô
# (ý) tín
# (a)
#
# (c) chữ
# (u) gân gó
# (n)
#
# (i)
#
# (c) nh
# (c) biê
# (c) thu
# (t) u, tô
# (c) giun đốt
#
# (c) lớp giun
# (c) gi
# (n) đập
# (o) cho r
# (t) A.D.
# (c) họ na
#
# (u) ngón n
# (u) có đố
# (u) có đố
# (c) có đốt
#
# (c) mang bào
# (ý) (th
# (ý) cực
# (ý) (th
# (c) là
# (c) trạng t
# (c) tỉnh nh
# (c) (thuộc) đi
# (c) có quả bấ
# (c) họ na
#
# (g) an
# (c)
#
# (c) ch
# (c) ch
# (c) vô c
# (c) ch
# (c) không có
# (c) sự
# (c) sự
# (c) lo
# (c) con kiến
#
# (c) loài thú
# (u)
#
# (c) kiến sư t
# (c) là
# (c)
#
# (c)
#
# (c) ch
# (c) chất
# (c) làm
# (c) Na
# (c) ch
# (c) ch
# (i) số ti
# (t) a.m.
# (t)
#
# (c) loài linh
# (c) bu
# (ọ)
#
# (ọ)
#
# (c) râ
# (c) râ
# (.)
#
# (c) thứ ba kể
# (c) thứ ba kể
# (g) áo nhậ
# (g) áo nhậ
# (c) bao phấn
#
# (c) (thuộc) b
# (c) túi đực
#
# (c) có bao ph
# (c) sự nở hoa
# (c) Antoxian
# (c),  (t
# (c),  (th
# (c),  (th
# (c) antr
# (c) cụ
# (c) (t
# (c) an
# (c) dạ
# (c) cụ
# (c) nh
# (c) ph
# (c) ph
# (c) th
# (t) chịu
# (ự) chốn
# (ự) sát
# (ư)
# (e)
# (ỹ) (quân sự) n
# (c) cây sui
#
# (g) số n
# (t) (thuộc) nếp
# (t) nếp lồi
#
# (g) xoáy n
# (c) xo
# (a)
#
# (t) hoá c
# (ô) sự
# (c) đối l
# (c) ch
# (m)
#
# (m)
#
# (ỹ) chống tăng
#
# (ỹ) chống tăng
#
# (c) anti
# (c) an
# (c) Anti
# (c) anti
# (c) anti
# (ỹ) phản nơtron
# (c) ph
# (i)
#
# (ỹ) người phản
# (ý) Ant
# (c) Antip
# (c) Antip
# (c) kh
# (c) cây hoa m
# (t) không
# (c) hồ
# (c) ch
# (c) ph
# (c) ph
# (c) kh
# (p) chống lại
# (c) ch
# (i)
#
# (c) phép
# (u) hang
#
# (ổ),  (thơ ca)
# (u) hang
#
# (g) an
# (c) bộ không
# (c) không có
# (c) bệ
# (u) hậu mô
# (t) nào đó
# (c) một ng
# (i)
#
# (u) binh
# (c) bất định
#
# (c) (thuộc) t
# (u) động m
# (c) độ
# (g)
#
# (c) nguỵ tran
# (t) Apatit
#
# (t)
#
# (i) thẳng
# (c) ch
# (c) ch
# (c) không cán
# (c) hiện tượn
# (c) ch
# (c) ng
# (c) (t
# (c) điểm xa m
# (c) điểm xa m
# (c) hướng ngư
# (c) tính hướn
# (ừ)
#
# (c) hi
# (ừ)
#
# (c) giống rệp
# (c) gi
# (c) giống rệp
# (c) ch
# (c) ch
# (c) cá
# (c) cá
# (c) bệ
# (c) bệ
# (c) không lá
#
# (c) ng
# (c) đỉ
# (c) ng
# (c) kh
# (ý) kín
# (ý) tươ
# (ý) tín
# (c) sự
# (o) sự kh
# (o) (thuộ
# (o) (thuộ
# (c) có lá noã
# (ý) kín
# (ý) tiê
# (ý) tín
# (c) hiện tượn
# (o) kinh
# (c) ki
# (c) (thuộc) h
# (t)
#
# (t)
#
# (c) sinh sản
# (c) sự sinh s
# (c) điển xa qu
# (o)
#
# (p)
#
# (u) cân
#
# (u) cân
#
# (c) cá
# (u) mỏm, m
# (c) ng
# (c) ch
# (i) ở phí
# (i)
#
# (n)
#
# (u)
#
# (c) tô
# (c) tô
# (c) hô ngữ
#
# (ổ) người bào c
# (c) quả thế đ
# (c) quả thế đ
# (c) đường
# (g)
#
# (m)
#
# (c) lạ
# (ý) có t
# (ý) chốn
# (ý) (thu
# (c) chung (từ
# (ý) bên
# (c) th
# (c) bệ
# (c) có phần p
# (c) tổng gi
# (c) tổng gi
# (c) về
# (n)
# (g)
#
# (o)
#
# (ỹ) rượu táo
#
# (t)
#
# (ỹ),  (thông tụ
# (ỹ),  (thông tụ
# (c) cây táo
#
# (g) ap
# (g) ap
# (o)
#
# (c) nốt
# (ì)
#
# (u),
# (ổ) (như) appra
# (p),  (thông t
# (ỹ) tán thành,
# (r) thích h
# (g)
#
# (ự) chỗ
# (ư)[
# (g); hậu cung
# (c) ch
# (c) cùng điểm
#
# (c) cùng điểm
#
# (c) không cán
# (ư)
# (c) nước
# (n)
#
# (t)
#
# (o) ván trượt nướ
# (t) tranh m
# (h)
#
# (h)
#
# (h)
#
# (c) cung Bảo b
# (o) những môn thể
# (c) sự h
# (c) nư
# (t) lớp ngậm nướ
# (c) ch
# (c) A-
# (t)
#
# (t)
#
# (c) (thuộc) h
# (c) động vật
# (u) màng n
# (c) (thuộc) h
# (c) cây bách
# (c) sự
# (ý) ngườ
# (ỹ),  Uc ngày h
# (c) câ
# (u)
#
# (u)
#
# (c) ng
# (t) hình dạn
# (c) cây dương
# (c) đèn c
# (p)
#
# (c) vù
# (p)
#
# (c) th
# (c) kh
# (c) chim thuỷ
# (o) tổng
# (o) (thuộ
# (c) địa
# (c) hoà
# (t) (thuộc) đại
# (c) cá tôxôt
#
# (c) nguyên bà
# (c) nguyên bà
# (ự),  (t
# (c) ph
# (ự),  (t
# (c) tổ
# (c) rau ocxen
# (p)
#
# (c) Ac
# (c) th
# (c) ki
# (c) Acsitr
# (c) th
# (c) bắ
# (2)
#
# (c) cây cau
#
# (ã)
#
# (c) sống tron
# (c) cò già (Â
# (c) bạ
# (m)
#
# (c) đấ
# (c) Agon
# (c) A-gô-nốt (người
# (c), th
# (c) A-guýt (người tr
# (c) có hoa mà
# (c) có lá màu
# (c) Aria
# (t)
#
# (c) cung Bạch
# (c) áo hạt
#
# (c) Ariô
# (c) râu ngọn
# (c) râu ngọn
# (c) có râu ng
# (c) dò
# (c) dò
# (c) A-
# (c) số
# (g) tiền đặt cọc
#
# (c) con tatu
#
# (h) nơi chi
# (ự) áo g
# (c) Ac
# (y)
#
# (ỹ) (như) armou
# (ỹ) (như) armou
# (c) hu
# (ề)
# (c) ngư
# (ự) đạn
# (ự) bắn
# (.)
#
# (ự) thịt
# (ự) danh
# (ỹ) (như) army-
# (c) cây kim s
# (c) dòng họ r
# (c) hợp
# (.)
#
# (u) việc
# (h)
#
# (c) ch
# (.)
#
# (n) đến, t
# (c) cây hoàng
# (n) & (nghĩ
# (c) Asen
# (c) Asen
# (c) Asen
# (c) arse
# (c) Asen
# (.)
#
# (.)
#
# (ô)
#
# (u) (thuộc
# (u) biến
# (u) biến
# (c) xơ
# (c) th
# (u) động m
# (c) (t
# (c) vi
# (c) động vật
# (u) khớp
#
# (c) cây atisô
# (c) kh
# (u) khớp
#
# (ự) pháo
# (ự) pháo
# (ự) pháo
# (c) có guốc c
# (c) có guốc c
# (u) nghệ
# (c) ng
# (c) ng
# (c) làm ra
#
# (c) cây chân
# (c) ng
# (c) cây a ngu
# (t) miăng
#
# (c) gi
# (o) lễ th
# (c) nang (nấm
# (c) hải tiêu
#
# (c) (thuộc) h
# (c) lớp nấm n
# (c) Asco
# (c) nang bào
# (c) nang (nấm
# (c)
#
# (c) tính chất
# (g) số n
# (c) sự l
# (c) chất
# (ư)[
# (c); kỹ
# (c) lửa
# (ư)
# (.)
#
# (c) tr
# (t) đĩ
# (c) đá khố
# (c) đá khố
# (c) Ch
# (c) gi
# (c) rắn mào (
# (c) măng tây
#
# (c) cây dương
# (c) nấm cúc
#
# (.)
#
# (c) nh
# (c) lan nhật
# (c) sự
# (c) sự
# (a) rắn
# (n)
#
# (c) bật hơi (
# (t) máy h
# (t) thiết tha, mon
# (c) atpir
# (.)
#
# (c) cây a ngu
# (i)
#
# (ý)
#
# (ý)
#
# (ý)
#
# (i)
#
# (t) dây c
# (t) phân
# (ỹ) uỷ viên hội
# (.)
#
# (.)
#
# (.) để đánh thuế; đá
# (t) để đ
# (.) để đánh
# (u) tài s
# (c) đọc thành
# (c) sự đọc th
# (ý) ngườ
# (.)
#
# (ỹ) việc được g
# (n) & (nghĩ
# (n) & (nghĩ
# (n) & (nghĩ
# (n) & (nghĩ
# (+) việc
# (ổ) tha tội, xá
# (n)
#
# (a) có
# (n); an ủi, k
# (.)
#
# (.)
#
# (ý) phi
# (c) cây cúc t
# (i)
#
# (u) không
# (c) hành tinh
# (c) sự
# (c) su
# (c) bệ
# (c) lo
# (c) ch
# (c) không có
# (c) đường
# (u) xương
# (c) sa
# (m) buộc chặt
#
# (c) tí
# (c) là
# (a)
#
# (c) th
# (c) th
# (c) th
# (c) th
# (t)
#
# (c) đường
# (c) tiệm
# (c) không có
# (c) sự bỏ liê
# (í)
#
# (ỹ),  (từ lóng)
# (h)
#
# (c) Atabr
# (c) sự lại gi
# (c) lại giống
# (c) mấ
# (ỹ) ăn cơm
#
# (c) th
# (c) th
# (c) th
# (c) ch
# (u) điền
# (c) cột tư
# (c) nú
# (ý) cái
# (c) qu
# (c) qu
# (n) thích sử
# (c) ng
# (c) ng
# (i)
#
# (c) mấ
# (c) sự
# (c) bị
# (c) bị
# (o)
#
# (c) Atrop
# (ỹ) (như) at-a-
# (.)
#
# (c)
#
# (ý) sự đ
# (ý) sự t
# (ý) ngườ
# (c) th
# (ý) hút
# (ý) sự
# (c) (thuộc) t
# (.)
#
# (c) khúc
# (c) cà tím
#
# (c)
#
# (ố)
# (.)
#
# (ý) tri
# (h)
#
# (c) sự
# (c) sự
# (c) sự
# (t) Ogit
#
# (c) gia tố, y
# (ổ) thầy bói
#
# (c) th
# (c) chim anca
# (t) ng
# (c) tr
# (n)
#
# (.); tinh
# (c) hư
# (c) con sứa
#
# (c) (thuộc) l
# (c) và
# (t)
#
# (c) cây tai g
# (c) cây tai g
# (c) ta
# (c) chòm sao N
# (ể)
# (c) th
# (c) bò rừng C
# (c) bì
# (c) ng
# (c) sự
# (.)
#
# (u) sự ch
# (c) nư
# (c) nư
# (c) ch
# (c) ch
# (c) ch
# (c) ch
# (c) tá
# (c) xe ô t
# (ổ); sự hành tội hoả thiêu
#
# (c) máy t
# (c)
#
# (c)
#
# (c) tự
# (c) tự
# (o) độc l
# (ý) tự
# (c) tự giao
#
# (c) tự sinh
#
# (c) sự tự sin
# (c) sự
# (c) sự ưu tiê
# (ỹ) quán ăn tự
# (ỹ) xe ô tô
#
# (c) sự
# (c) (t
# (c) (t
# (ỹ) súng tiểu l
# (c) tự
# (c) sự
# (c) tự
# (c) tự dưỡng
#
# (ỹ) xe tải
#
# (c) mù
# (c) cái đo si
# (t)
#
# (t) của[a
# (y)
#
# (i) đứng
# (c) thiên thần giáng
# (ổ), (đùa cợt)
# (u); lời chào
# (c) lo
# (u)
#
# (g) máy bay
# (ứ)
#
# (i) tàu t
# (c) bệ
# (c) lê tàu
#
# (c) chim mỏ c
# (c)
#
# (c) chim mỏ c
# (c) ch
# (o)
#
# (a)
# (o) cuộc đấu ở sâ
# (o) cuộc đấu ở sâ
# (a) mệt
# (y)
#
# (c) hình giùi
# (c) râu (ở đầ
# (u)
#
# (ự) nghỉ
# (c) tr
# (c) nách lá
#
# (u) nách
#
# (u) nách
#
# (u) (thuộc
# (t) trục
# (t) ổ trụ
# (t) hộp ổ
# (t) cái c
# (t) trục
# (c) trục
# (c) khỉ aiai
# (c) cây khô (
# (c) th
# (c) gó
# (c) bèo dâu,
# (c) nitơ
# (c) nitr
# (t) azurit
#
# (c) đơn (tĩnh
# (t) của B
# (u)
#
# (t) hợp k
# (n)
#
# (n)
#
# (a) trẻ
# (h) (Babel)
# (h)
#
# (c) khỉ đầu c
# (p)
#
# (g)
#
# (c) người giữ
# (i) trò c
# (c) th
# (u) buổi
# (c) th
# (c) thần rượu Bắc-cú
# (c) có quả mọ
# (c) ăn quả mọ
# (c) thuốc
# (ư)
# (c) kh
# (t)
#
# (h)
#
# (n) & bóng
# (.) cũ
#
# (ỹ) đằng sau
#
# (y)
#
# (h)
#
# (a) (Uc)
#
# (.)
#
# (a)
# (o) hàng tam vệ (
# (ỏ)
#
# (t) khe,
# (.)
#
# (c) lời cã
# (.)
#
# (ỏ)
#
# (o) cú ve, quả tr
# (c) những
# (n) & (ngh
# (u) cầu t
# (i) ((thư
# (ư)
# (h)
#
# (c) rừ
# (u) rừng
# (c) vi
# (c) vi
# (ỹ) vùng đất đa
# (á)
#
# (g) người bán hàn
# (g)
#
# (o) cầu lông
#
# (t) màng
# (t) bộ gi
# (o) gậy đánh gôn
#
# (y),
# (ỹ) hành lý
#
# (.) của quân
# (ỹ) toa hành lý
# (ỹ) xe lửa chở
# (ỹ) giấy biên n
# (ỹ) người khuân
# (ỹ) nhân viên (
# (ỹ) phòng (để)
# (ỹ) nhãn (đề tê
# (a
# (g)
#
# (t)
#
# (t)
#
# (ý) tiền
# (ý) có t
# (i)
#
# (g)
#
# (a)
# (i), ng
# (t) đứ
# (ư)
# (ế)
#
# (ò)
#
# (.)
#
# (c) đàn
# (p) tờ quyết t
# (ồ)
#
# (t) xpinen đ
# (a)
#
# (u)
#
# (c) cây bụt m
# (c) chim sâm
# (ờ)
#
# (ờ)
#
# (c) chim sâm
# (c) ch
# (.)
#
# (i)
#
# (a) tai
# (t) ổ bi
#
# (ự) vỏ đ
# (g)
#
# (ự) (thu
# (ự) tên
# (ự) chuy
# (ự) đạn
# (.)
#
# (c) dây tấm p
# (g) khỉ
# (ỹ) sự quảng cá
# (g) chơi
# (c) con ve sầ
# (c) kh
# (c) (thuộc) h
# (ổ),  (từ lóng)
# (g) bịp,
# (g) sự b
# (g) kẻ b
# (c) cây chuối
# (h) nước cộng
# (.)
#
# (ữ)
#
# (ữ)
#
# (c) chuột gộc
# (n)
#
# (n)
#
# (.)
#
# (ỹ),  (từ lóng)
# (n)
#
# (n)
#
# (ỹ),  (thông tụ
# (i) ngày
# (c) cây đa
#
# (c) đàn
# (á)
#
# (ỹ) giấy bạc
#
# (ỹ) đầu đề chữ
# (t) bá
# (ự) chỗ
# (c) (Ê-cốt) nữ thần
# (h)
#
# (c) ph
# (c) cây baoba
# (t) ổ
# (o) rửa t
# (o) lễ rử
# (o) (thuộ
# (o) người
# (o) nơi r
# (o) nơi r
# (o) rửa t
# (t)
#
# (c) ngựa bác
# (c)
#
# (c)
#
# (c) có râu; c
# (u) nướn
# (c) cá râu (l
# (c) giống cây
# (c) giống cây
# (c) cu rốc (c
# (i)
#
# (.)
#
# (c) bacb
# (m)
#
# (ơ)
#
# (ơ)
#
# (a) thi
# (a)
#
# (ỹ),  (từ lóng)
# (n)
#
# (c) bari
# (c) giọn
# (c) bari
# (ỹ) chủ quán rư
# (g) súng
# (n)
#
# (ỹ) dao nhíp lớ
# (u)
#
# (c) chim lợn
#
# (ư)
# (c) ngỗng trờ
# (ý) biể
# (ý) máy
# (ý) pho
# (ý) (th
# (ý) (th
# (c) na
# (ý) cái
# (g) số n
# (c) cá nhồng
#
# (c) đàn
# (g) động tá
# (t)
#
# (ủ)
#
# (ủ)
#
#
# (ư)
# (ư)
# (g) wh
# (m)
#
# (c) bari
# (t) bazan
#
# (c) ba
# (t)
#
# (ý) tần
# (o) bóng chày
#
# (o) cầu thủ bóng
# (.)
#
# (ỳ)
#
# (t) của B
# (c) tính
# (c) đảm của n
# (c) nấm đảm
#
# (c) đảm của n
# (c) cây húng
# (u) basili
# (ổ) La-mã hoàng
# (c) rắn thần
#
# (ỹ) bữa ăn tron
# (ỹ) bữa ăn tron
# (ỹ) cuộc đi chơ
# (o) bóng rổ
#
# (y),
# (c) cá pecca
#
# (c) viôl
# (c) cây đoạn
#
# (n)
#
# (c) giọn
# (c) kèn
# (c) libe
#
# (g)
#
# (c) chồi rễ
#
# (y)
#
# (o) gây (đánh bón
# (.)
#
# (h)
#
# (n)
#
# (h) xe (
# (i)
#
# (.)
#
# (n)
#
# (n)
#
# (t) lối in
# (o)
#
# (t)
#
# (c) ếc
# (o) vận động viên
# (ự) tiểu
# (n)
#
# (o) vận động viên
# (c) phi
# (ự) khẩu
# (o) sự đánh (bóng
# (c) rìu
# (i) tàu t
# (o) vợt chơi cầu
# (ư)
# (g) số n
# (i) tàu c
# (n) sự s
# (g) điên
# (t) bauxit
#
# (t) đồ
# (i)
#
# (c) cây nguyệ
# (ứ
# (g)
#
# (g)
#
# (ự) súng
# (n)
#
# (ự) vị t
# (ự) sĩ q
# (n)
#
# (t)
#
# (o) thầy
# (m)
#
# (c) xà, rầ
# (ỷ)
#
# (n)
#
# (.)
#
# (ỹ),  (thông tụ
# (g) (như
# (h)
#
# (i); (
# (.); người kh
# (.)
#
# (ỹ) thanh niên
# (a) đẹp
# (ỹ) người chủ m
# (m)
#
# (t)
#
# (c) con hải l
# (ỹ) nhạc bibôp
# (i)
#
# (g)
#
# (g)
#
# (t)
#
# (t)
#
# (ữ)
#
# (h)
#
# (m)
#
# (.)
#
# (t)
#
# (c) ch
# (c) con ong
#
# (c) chim trảu
# (c) cây sồi
#
# (c) câ
# (t)
#
# (i)
#
# (c) bi
# (g) wa
# (c) cây củ cả
# (g) cái
# (n) & (ngh
# (c) cây thu h
# (.)
#
# (.)
#
# (n)
# (c) chủ ng
# (a) chỉ
# (ổ) on (for,  t
# (n) & bóng
# (n) lại
# (n) lại
# (t) con tên đá (
# (c) Bỉ
# (ổ) có lẽ, khôn
# (.)
#
# (i) phao
# (c) giống cây
# (.)
#
# (ỹ),  (từ lóng)
# (n)
#
# (ờ)
#
# (c) cây benla
# (c) vă
# (.)
#
# (ò)
#
# (c) bệnh đ
# (a)
#
# (y)
#
# (i)
#
# (ỹ) đường xe đi
# (c) ngà
# (ì)
#
# (g) bữa
# (c) sự
# (à)
#
# (o) tiền
# (c) Bă
# (c) Bă
# (i)
#
# (ổ) sự ban ơn,
# (ư)
# (c) sinh vật
# (c) Be
# (c) Benz
# (c) benz
# (c) benz
# (c) Benz
# (ư)
#
# (ư)
#
# (c) giống cây
# (c) lúa mạch
#
# (i)
#
# (i) núi,
# (c) bệ
# (c) ngỗng trờ
# (c) có quả mọ
# (c) quả mọng
#
# (a)
#
# (t) berin
#
# (c) beri
# (ẻ)
#
# (n) & (ngh
# (ự) bao
# (g)
#
# (g)
#
# (g)
#
# (a) rải
# (c) người
# (ỹ),  (thông tụ
# (c) sú
# (p)
#
# (ý) tia
# (ý) bêt
# (c) cây trầu
# (c) cây hoắc
# (ổ) (như) betwe
# (t) bánh
# (t) sự tr
# (i); đàn (chim)
#
# (p)
#
# (ổ) vô tình mà
# (ỳ)
#
# (o)
#
# (ý) hai
# (n)
#
# (c) ki
# (h)
#
# (c) th
# (c) th
# (c) cacb
# (ộ)
#
# (u) có hai
# (c) đicl
# (c) đicr
# (ý) hai
# (ý) hai
# (.)
#
# (ỹ) (như) bicyc
# (á)
#
# (á)
#
# (g) cú đ
# (n)
#
# (t)
#
# (g) nhân
# (ự) pháo
# (ỹ) người làm b
# (ỹ),  (từ lóng)
# (g) (như
# (ỹ) sự phô trươ
# (c) (từ Mỹ,ng
# (n)
#
# (c) (viết
# (c) hai môi (
# (c) cây việt
# (c) cái
# (n)
#
# (c) sỏ
# (c) mậ
# (c) mậ
# (ợ)
# (o)
#
# (ỹ) bảng dán th
# (n)
#
# (c) nghìn
# (ỹ) nhà tỉ phú
#
# (c)
# (i) thuyề
# (i)
#
# (ệ)
#
# (ệ)
#
# (.)
#
# (c) ha
# (ỹ) hiệu đóng s
# (ỹ),  (từ lóng)
# (c) giống cây
# (c) chồi
#
# (g) cuộc
# (i) hộp l
# (c) nhị t
# (g) cô g
# (c) ho
# (c) th
# (c) th
# (c) ti
# (c) ti
# (c) si
# (c) si
# (c) si
# (c) si
# (c) kỹ thuật
#
# (c) lý
# (c) sinh chất
# (c) si
# (c) ha
# (c) chia đôi
# (t)
#
# (t)
#
# (c) hai c
# (c) trùng
# (c) cây anh t
# (m)
#
# (ỹ),  (thông tụ
# (i) quãng
# (ư)
# (ư)
# (c) lưỡng tín
# (c) bitm
# (c) cây quyền
# (c) da
# (c) sunf
# (.); mảnh m
# (g) bitc
# (n) & (nghĩ
# (ư)
# (c) con vạc
#
# (t) tí
# (i) cọc b
# (c) có h
# (c) hai mảnh
# (ự) trại
# (c) (như)
# (.)
#
# (ư)
# (h)
#
# (t) secnôzem đất
# (h)
#
# (ự)
#
# (.)
#
# (g)); kẻ thà
# (c) con gián
#
# (t)
#
# (t) grafit
#
# (g)
#
# (ý
# (c) cây mâm x
# (c) chim hét
#
# (y); xi (đ
# (g); kẻ phản bội
#
# (c) cây mận g
# (c) người
# (m)
#
# (c) cây việt
# (ỹ) lời nói huê
# (c) mụ
# (.)
#
# (ò), h
# (t) lò ca
# (c) mầm gốc,
# (c) bì phôi
#
# (c) người
# (c)
#
# (i)
#
# (i)
#
# (t)
#
# (ê)
#
# (a)
#
# (a)
#
# (m); lẫn tránh
#
# (.) pha trộn
#
# (t) blenđơ,
# (.) pha trộn
#
# (á)
#
# (c) người
# (c) người
# (i)
#
# (ự),  (t
# (g) sự lái
# (u) ruột t
# (ỹ),  (từ lóng)
# (u) điểm m
# (ỹ),  (từ lóng)
# (c) gác kh
# (ư)
# (ự) luỹ
# (i) che
# (.) (để
# (u) miếng
# (a) sun
# (c) ba hoa
# (a) sun
# (h)
#
# (ị) khối
#
# (.)
#
# (n)
#
# (g) bom
# (t) hệ thống tín
# (ự) lô c
# (c) gã, ch
# (c) ng
# (o)
#
# (g)
#
# (c) sự
# (u)
#
# (c) sự
# (h); tiền phạt trả cho người nhà có người bị giết
#
# (n)
# (t)
#
# (g) lỗi
# (o)
#
# (ả)
#
# (c)
#
# (a)
#
# (g) say
# (n)
#
# (ỹ),  (từ lóng)
# (i)
#
# (g) khóc
# (c) sự chá
# (c) ch
# (i) cờ lệ
# (i) giải
# (a)
#
# (h)
#
# (c) cây hoa c
# (c) cây cúc t
# (.)
#
# (c) sún
# (.)
#
# (n)
#
# (n)
#
# (g)
#
# (i) viên
# (i) viên
# (ề)
#
# (c) con trăn
# (i)
#
# (i) tạu k
# (o) cuộc đua thuy
# (i) viên
# (ồ); cục
# (g) nhan
# (g) cảnh
# (ỹ),  (thông tụ
# (c) linh miêu
# (c)
#
# (ữ)
#
# (g) ở từ
# (c) th
# (t)
#
# (a)
#
# (g) nhà
# (t) giá chuyển h
# (c) Bô
# (c) nh
# (t) gian
# (c) nóng n
# (g) mũi
#
# (y)
#
# (c) quả nang
# (i) cọc b
# (ý) cái
# (ỹ),  (từ lóng)
# (g)
#
# (c) viên
# (y)
#
# (m)
#
# (ể)
# (c) ken
# (n)
#
# (g)) mối qua
# (á)
#
# (n) & (nghĩ
# (n) & (nghĩ
# (g) ngườ
# (n)
#
# (c) xe đạp
# (c) chai c
# (g) ở từ
# (n)
#
# (g) lầm
# (c) cá ngừ
#
# (t); mũ phụ nữ,
# (g)) cừ, tuyệt
# (u)
#
# (ỹ) người ngốc
# (a) cho vui
#
# (u)
#
# (u)
#
# (g) để l
# (h)
#
# (h)
#
# (h)
#
# (.)
#
# (ỹ) ô tô thư vi
# (ỹ) hiệu sách
#
# (n) & (nghĩ
# (i) sào c
# (c) con cangu
# (m)
#
# (ỹ),  (từ lóng)
# (c) sự quả
# (ỹ),  (thông tụ
# (ỹ) người đánh
# (ữ)
#
# (i)
# (n)
#
# (ỹ),  (từ lóng)
# (c) bori
# (c) bora
# (c) bora
# (ỹ) nhà thổ, nh
# (ỏ)
#
# (a) thầ
# (c) cải xoăn
#
# (c) bori
# (g)
#
# (c) Bo
#
# (g) phát
# (g) phát
# (t) bụng
# (g) ông
# (c) th
# (c) th
# (t) cá
# (t) cá
# (ể)
# (o) người chăm só
# (c) giống cây
# (g)
#
# (i) sự mư
# (t)
#
# (c) ch
# (m)
# (g) anh
# (ỹ) kẻ phản độn
# (a) chồ
# (c) gi
# (c) cửa sổ
# (a)
#
# (h)
#
# (h)
#
# (u) ruột
#
# (i) neo đ
# (g) bo
# (ỹ) cái mác (để
# (g) bo
# (m)
# (i) tên
#
# (i) rầm n
# (ỹ) toa chở hàn
# (a)
#
# (t)
#
# (t)
#
# (.)
#
# (a)
#
# (g) tình
# (n) (th
# (y),
# (.)
#
# (à)
#
# (a)
#
# (c) tr
# (c) ((viết
# (ể)
# (g)
#
# (u) (thuộc
# (c) động vật
# (i)
#
# (c) cây dương
# (c) côngxo
# (c)
#
# (c) lá bắc
#
# (c) (thuộc) l
# (c) có lá bắc
# (c) lá bắc co
# (c) lá bắc co
# (.)
#
# (g)
#
# (o) người
# (o) người
# (c) đạ
# (o)
#
# (i) dây c
# (ù)
#
# (c) con đẻ
# (t)
#
# (c) bệ
# (c) bệ
# (c) sọ
#
# (n)
#
# (c) nguồn
# (ỹ) các chuyên
# (a)
#
# (g) br
# (t) toa phanh ((
# (ỹ) người gác p
# (ỹ) người gác p
# (c) chim xẻ n
# (c) mang (cá)
# (c) mang (cá)
# (c) ma
# (á)
# (á)
#
# (c) cây ô rô
#
# (ự),  (t
# (.)
#
# (i),  (từ
# (n); quán bi
# (g), gi
# (ỏ) vách
# (u)
#
# (c) cây vang
#
# (.)
#
# (ỹ) hàng người
# (ả) gia đình; la
# (e)
#
# (ự) sự c
# (.), sự
# (.)
#
# (a)
#
# (g)
#
# (o)
#
# (o) kiểu bơi ếch
#
# (u) xương
# (ự) công
# (g)
#
# (g)
#
# (i)
#
# (t)
#
# (ý) lò
#
# (ự) xe x
# (ự) hàm
# (o) sách
# (n) chữ c
# (a); sự p
# (c) cây thạch
# (u)
#
# (i) brit
#
# (a)
#
# (c)
#
# (a)
#
# (ự) chỉ
# (c)
#
# (ư)
#
# (c) quần đ
# (c) cây thạch
# (i) thuyề
# (ự) lữ đ
# (c) bệ
# (c) cá bơn vỉ
# (c)
#
# (n)
#
# (n)
#
# (c)
#
# (c) cây nhăng
# (i)
#
# (t)
#
# (.)
#
# (a) nướ
# (c) nư
# (c) An
# (ỹ) người Anh
#
# (m)
#
# (t)
#
# (c) đậu tằm
#
# (.)
#
# (.)
#
# (.)
#
# (i) phần
# (c) con lửng
#
# (i)
# (.)
#
# (.)
#
# (a)
#
# (c)
#
# (g) ô, d
# (c) brom
# (c) thuộc họ
# (c) brom
# (c) brom
# (c) brom
# (u) cuống
# (u) cuống
# (c) cu
# (c) (t
# (c) bệ
# (a)
#
# (c) vi
# (c) bư
# (a)
#
# (u); ghi
# (.)
#
# (i)
#
# (c) cây đậu c
# (t) của b
# (m)
# (m)
# (i)
#
# (c) ch
# (n)
#
# (c)
#
# (ự) súng
# (ỹ) đá cát kết
# (á)
#
# (i), vết th
# (ổ) tin đồn, ti
# (c) mù
# (c) ngựa c
# (a) sươ
# (g) bữa
# (n)
#
# (ỹ),  (thông tụ
# (c) cải bruxe
# (u)
#
# (c) cây nhăng
# (c) rêu
#
# (t) gà
# (c) bệ
# (c) bệ
# (c) th
# (u) cơ mút
# (n)
#
# (c)
#
# (.)
#
# (i),  (từ
# (.)
#
# (g) khôn
# (g) ngườ
# (c) mụ
# (c) đạ
# (c) đạ
# (p) sự ghép
# (ỹ),  (thông tụ
# (c) ng
# (t) vật đ
# (n)
#
# (a)
#
# (ỹ),  (từ lóng)
# (c) người
# (ư)
# (ỹ),  (từ lóng)
# (c) cây hạ kh
# (ự) lính
# (.)
#
# (.); (thực vậ
# (c) hành con
#
# (c) Bu
# (c) ch
# (c) cu
# (c) ch
# (i) trọng
# (i) vách
# (ì); tầm vóc to
# (ì); tầm vóc to
# (ỹ),  (thông tụ
# (a)
#
# (a)
#
# (c) con vạc
#
# (c) cây mận r
# (m)
#
# (t);
# (t);
# (c)
#
# (a)
#
# (c) chin sẻ ứ
# (c) cá bống b
# (c)
#
# (c)
#
# (c) (như)
# (g) chơi
# (c) cây hương
# (i) tàu t
# (n)
#
# (ư)
# (c) ong nghệ
#
# (ỏ)
#
# (g) giấy
# (n)
#
# (ỹ) người vô cô
# (g)
#
# (ỹ),  (từ lóng)
# (ỹ),  (từ lóng)
# (g) sự đ
# (a)
#
# (i) kho t
# (ỹ),  (thông tụ
# (ỹ)
#
# (i) bụng,
# (i) phao,
# (i) sự th
# (t)
#
# (c)
#
# (c) cá tuyết
# (n) & (nghĩ
# (g); bọn q
# (c) qu
# (c) Bure
# (ỹ),  (thông tụ
# (i) cờ đu
# (a) chồ
# (t) th
# (n)
#
# (c) mũ
# (i),  (từ
# (.)
#
# (t) chỗ thắ
# (c) Mi
# (c) Mi
# (t) (t
# (g) tron
# (m)
#
# (c)
#
# (p)
#
# (p)
#
# (g) sự ợ
# (ư)
# (c) má
# (ỹ),  (thông tụ
# (ỏ)
#
# (u) bìu, t
# (u) bìu, t
# (h)
#
# (c)
#
# (c) (thuộc) h
# (m)
#
# (c) sự suy
# (n) & (nghĩ
# (ỹ) anh hầu bàn
# (ỹ) cô hầu bàn
# (a)
# (c)
# (ỹ) quân du kíc
# (.)
#
# (ỹ) thợ sửa quầ
# (n)
#
# (a)
#
# (ổ) cai hôn
#
# (c) chim ôtit
# (g) ((th
# (ỹ),  (từ lóng)
# (c) buta
# (c) buta
# (.)
#
# (y);
# (c) cây mao l
# (t) tai h
# (t) ốc ta
# (h)
#
# (u) mông
# (o)
# (c) trụ ốp
# (c) bạn, b
# (c) buty
# (ọ); ti
# (ự) phi
# (.)
#
# (i)
#
# (.)
#
# (h)
#
# (ừ)
#
# (ư)
# (ư)
# (h) ((cũng) cabaret)
#
# (i)
#
# (c) ph
# (c) người
# (t)
#
# (y)
#
# (y)
#
# (ý)
#
# (ư)
# (y) cáp
#
# (y) cáp
#
# (g)
#
# (i) bếp t
# (ư)
# (c) cây cacao
# (c) cá nhà tá
# (y)
#
# (c) su
# (c) bệ
# (n)
#
# (c) caco
# (u)
#
# (c) họ
# (c) cây xương
# (c) cây xương
# (c) uốn lưỡi
# (c) đị
# (c) (t
# (n)
#
# (g) te
# (ọ)
#
# (h)
#
# (c)
# (p)
#
# (c) catm
# (u) ruột t
# (u) ruột t
# (c) (thuộc) h
# (c) th
# (c) xezi
# (a) sự
# (ỹ) quán ăn tự
# (c) cafêi
# (g)
#
# (ỹ),  (thông tụ
# (ỹ),  (thông tụ
# (ỹ),  (thông tụ
# (ỹ),  (từ lóng)
# (c) cá sấu (t
# (t) (thuộc) đại
# (i)
#
# (ổ),  (thơ ca)
# (c) nho cajơp
# (n)
#
# (g)
#
# (c) cây bí đặ
# (g)
#
# (ỹ),  (thông tụ
# (c) con mực b
# (t) calamin
# (c) rau phong
# (c) cây lô mộ
# (c) cây thạch
# (t) máy c
# (c) đá
# (c) đá
# (c) cây huyền
# (c) sự h
# (t) canxit
#
# (c) canx
# (s) (toán học) phép
# (c) có
# (s) (toán học) phép
# (u)
#
# (a) (th
# (c) là
# (g)
#
# (t) máy c
# (ũ)
#
# (y) ((cũng) calf)
#
# (ỹ) (như) calib
# (.)
#
# (.)
#
# (n)
#
# (u) khoang
# (u) khoang
# (.)
#
# (u)
#
# (i)
#
# (h)
#
# (h)
#
# (h)
#
# (ự) lệnh
# (g)
#
# (c) th
# (n)
#
# (n)
#
# (m)
#
# (a)
# (t); lặng,
# (c) là
# (c) calo
# (ý) sự
# (c) ca
# (ư)
# (c) ph
# (u)
#
# (ự) chôn
# (h)
#
# (h)
#
# (i)
#
# (c) đài (hoa)
# (c) đài (hoa)
# (t) cam
#
# (t) trục
# (.)
#
# (c) tầng phát
# (ể)
# (t) (thuộc) camb
# (ể)
# (c) cây hoa t
# (c) hươu cao
# (ự) đội
# (à)
#
# (c) cúc La mã
# (n) & (nghĩ
# (c) bệ
# (o),  (từ
# (c) giống cây
# (c) (thuộc) h
# (c) hình chuô
# (ỹ) khu sân bãi
# (c)
#
# (c) Ca
# (g) ca
# (c) hình mạng
# (c) hình mạng
# (u) xốp (x
# (c) un
# (ý) cađ
# (ỹ) sự ứng cử
#
# (ý) nến
# (ỹ) (như) cando
# (ỹ) kẹo
#
# (g) su
# (g) tr
# (c) ch
# (.)
#
# (c) bệ
# (n)
#
# (g) ca
# (c) đạn
# (g) ca
# (g)
#
# (ỹ),  (thông tụ
# (g)
#
# (c) đạ
# (c) dưa đỏ
#
# (c) dưa đỏ
#
# (c) cant
# (u) khoé m
# (u) khoé m
# (c) mút ch
# (ơ)
#
# (ự) sự c
# (ờ)
#
# (g) ngườ
# (i)
#
# (.); mũ (công nhân
# (c) điện
# (r) là
# (c) cây bạch
# (c) gà rừng
#
# (c) gà rừng
#
# (y)
#
# (ý) trát
# (ý) sự
# (c) tă
# (g) là c
# (g) là c
# (à)
# (i) sự ăn
# (c) khúc
# (c) dê
# (a)
#
# (c) cây ớt
#
# (n)
#
# (p)
#
# (c) quả nang
#
# (ư)
# (.)
#
# (n)
#
# (t)
#
# (i)
# (n) thầy
# (y)
#
# (ự) ngườ
# (i) (ngựa)
#
# (n)
#
# (a); giáp
# (m); đoàn người hành hương
#
# (c) thu
# (c) cây carum
# (ỹ) chỗ để xe đ
# (c) cacb
# (ự) ngườ
# (c) hyđa
# (c) cacb
# (y)
#
# (c) (thu
# (c) cacb
# (.)
#
# (t)
#
# (t) cacbu
# (t) cacbu
# (c) ch
# (c) un
# (c) un
# (ỹ),  (thông tụ
# (ỹ),  (thông tụ
# (c) cây bạch
# (t) khớp
# (c) ti
# (y)
#
# (c) chim giáo
# (c) bệ
# (c) vi
# (t)
#
# (ỷ) (để l
# (t)
#
# (ỷ)
#
# (c) cây rau m
# (c) tuần lộc
# (c) bệ
# (g); b
# (c) là
# (c) xá
# (c) cây cẩm c
# (t) cacnelia
# (c) phỉnh
# (c) sự
# (c) ho
# (i)
#
# (c) bộ ăn thị
# (c) loài ăn t
# (c) ăn thịt
#
# (c) phỉnh
# (g) vào
# (ỹ) cú đánh trú
# (u) động m
# (ư)
# (n)
#
# (c) cá chép
#
# (u) (thuộc
# (c) lá noãn
#
# (u) tiết
# (.) ở ngoài
# (ỹ),  (quân sự)
# (ỹ),  (quân sự)
# (y)
#
# (y)
#
# (i)
#
# (a)
#
# (g)
#
# (á)
#
# (.)
#
# (ự) tư t
# (n) sự m
# (c) hành đ
# (g)
#
# (ư)
# (ò)
#
# (ế) cact
# (c) th
# (c) thuyết
# (y);
# (c) sụ
# (c) th
# (c) th
# (g)
#
# (g) về c
# (.)
#
# (c) mào, mào
# (c) thu
# (c) cột tư
# (c) (thuộc) h
# (c) quả thóc
#
# (c) quả thóc
#
# (c) lị
# (ì); (k
# (c) lị
# (c) caze
# (ự) hầm
# (c) ph
# (u)
#
# (c) cây đào l
# (n) casơm
# (.)
#
# (c),  (
# (ý) sự h
# (c) cây sắn
#
# (c) đà điểu (
# (.); sự
# (g) ((th
# (c) cây thầu
# (u); danh sách những ngườ
# (n)
#
# (ỹ) gay gắt, qu
# (c) cây bạc h
# (n)
#
# (.)
#
# (c) sự dị hoá
# (c) chất dị h
# (c) ch
# (c) ch
# (c) (t
# (c) sự x
# (c) vật
# (c) xúc
# (c) xúc
# (c) vật
# (i)
#
# (c) th
# (c) ch
# (c) ch
# (c) ch
# (t) thuyết tai b
# (ể)
# (o) môn vật tự do
# (n)
#
# (ư)
# (o) sách
# (ổ) bạn chí thâ
# (ú)
#
# (c) sự
# (ý) cực
# (ý) cat
# (c) đuôi sóc,
# (ỹ) (như) cat-m
# (ý) phả
# (ý) môn
# (ư)
# (ò)
#
# (ư)
# (c)
#
# (ị)
#
# (c) (thuộc) đ
# (c) có đuôi
#
# (a) lãnh tụ
#
# (g)
#
# (u)
#
# (c) có thân
#
# (c) cải hoa,
# (u)
#
# (u)
#
# (c) ng
# (c) Cá
# (ý) danh
# (.)
#
# (i)
#
# (i)
#
# (c) ăn d
# (c) tính
# (c) đố
# (c) sự
# (c) đố
# (c) sự
#
# (c) hang
# (c)
#
# (c) cá sấu (t
# (ỹ) ngựa nhỏ (c
# (g) bóng
# (c) cây tuyết
# (.)
#
# (ả)
#
# (c) cây bông
# (à)
#
# (.)
#
# (c) cần tây
#
# (c) tr
# (.)
#
# (c) đàn
# (c) tế
# (u) tế bào
# (c) xenl
# (c) xenl
# (.)
#
# (à)
#
# (.) trong cu
# (a)
#
# (6)
#
# (p)
#
# (ỹ) (như) centr
# (p)
#
# (c) con rết
#
# (g)
#
# (c)
#
# (o) trung phong (
# (t)
# (t) đường ray gi
# (c) ch
# (c) ch
# (c) cây thùa
#
# (c) đầ
# (c) động vật
# (c) phần đầu
# (c) ng
# (p)
#
# (c) da gốc mỏ
# (c) ng
# (c) âm quặt l
# (u) não, ó
# (m)
#
# (ư)
# (c) ng
# (c) xeri
# (c) rá
# (c) chì
# (u) (thuộc
# (c) hư
# (ư)
# (.)
#
# (ỹ) hố phân
#
# (u)
#
# (c) sán dây
#
# (c) (thuộc) b
# (c) Xơ
# (g) ch
# (ư)
# (t)
#
# (t)
#
# (c) chim mai
# (n)
#
# (ô) sự
# (t) sự nối các t
# (c)
#
# (ý),  (
# (h)
#
# (ỹ) đoàn tù bị
# (á) hết đ
# (u) mắt xí
# (ỹ) cửa hàng dâ
# (ỹ),  (từ lóng)
# (ỹ),  (ngành đư
# (p)
#
# (t) chanxeđo
# (3)
#
# (ĩ)
#
# (u)
#
# (t)
#
# (ự) tiến
# (ự) có t
# (.)
#
# (c)
#
# (ự) hiệu
# (g)
#
# (.)
#
# (g)
#
# (c) tắc kè ho
# (á)
#
# (c) con sơn d
# (ư)
# (ư)
# (ý) tội
# (o) thánh
# (c); phủ
# (ư)
# (c) să
# (c) may rủ
# (ô)
#
# (ư)
# (c) đứa trẻ thay thế
# (o) thánh
# (ủ)
#
# (c) thằng,
# (.) bán rong
#
# (ỹ) quần (bằng)
# (.); buổi lễ ở nhà thờ nh
# (i)
#
# (i)
#
# (c) đầu cộ
# (h)
#
# (c) công t
# (t) của c
# (h)
#
# (c) giống cá
# (i)
#
# (n) & (nghĩ
# (n)
#
# (o) đại biệ
# (c) xe
# (ụ)
#
# (m)
#
# (m)
#
# (c) chòm sao G
# (c) bạch giới
# (p) người lái đò b
# (i) bản đ
# (i) người
# (n)
#
# (c)
#
# (c) pho
# (a)
# (t)
#
# (i) đại b
# (a) đầy
# (c) ly rượ
# (ũ)
#
# (.)
#
# (o) áo lễ
# (m);
# (c) cây chùm
# (c) sự nha
# (n) & (nghĩ
# (ỹ) (như) chequ
# (t) đai ố
# (ỹ) phòng gửi đ
# (e)
#
# (.)
#
# (ỹ) người tính
# (ờ) sự c
# (n)
#
# (g) chào
# (c) loài báo
# (c) loài dơi
#
# (c) (thuộc) b
# (t) thuộc thời k
# (n)
#
# (c) ho
# (c) lý
# (y)
#
# (c) ph
# (c) tính hướn
# (o)
#
# (c) (thuộc) h
# (n)
#
# (m) tiểu thiên sứ
#
# (m) tiểu thiên sứ
#
# (i)
#
# (ỹ),  (thông tụ
# (ỹ),  (thông tụ
# (c) cây hạt d
# (ỹ),  (thông tụ
# (c)
#
# (o)
#
# (a) sự p
# (ỳ)
#
# (ỳ)
#
# (ể)
# (m)
#
# (ỹ), cụi duây;
#
# (u) có ngự
# (ỹ),  (thông tụ
# (c) bệ
# (c) cây đậu t
# (c) rau diếp
# (ỹ) tổng thống;
# (m) (thuộc) người đ
# (t)
#
# (t)
#
# (n)
#
# (a) như
# (c) có dịch d
# (h)
#
# (p) quái vật đuôi
# (y)
#
# (c) con tinh
# (c) chào!
# (c) bệ
# (ỹ),  (từ lóng)
# (c) cây xoan
#
# (ố)
#
# (ỹ) con rệp
#
# (c) sóc sinsi
# (t) hẻm
#
# (ỹ),  (thông tụ
# (c) Tr
# (a)
#
# (a)
#
# (c) sóc chuột
# (c) sóc chuột
# (ỷ) 18 ở Anh)
#
# (ỹ) vui vẻ, hoạ
# (g) tính
# (g) khô
# (m)
#
# (ý)
#
# (g) pe
# (g) pe
# (c) bộ dơi
#
# (m);
# (g) ngườ
# (.)
#
# (c) chất kiti
# (c) kêu ríu r
# (ỹ) (như) chit-
# (.)
#
# (a) có
# (c) clor
# (c) clor
# (c) clo
#
# (c) cloro
# (c) táo lục
#
# (c) chất diệp
# (c) lạp lục
#
# (c) bệnh úa v
# (c) clor
# (n)
#
# (h) đầy
# (ờ)
#
# (ổ)
#
# (ổ) nước mắt
#
# (c) bệ
# (c) dị
# (c) hay ké
# (c) hay ké
# (ư)
# (g) nhan
# (.)
#
# (ó)
#
# (n)
#
# (a) dây
# (c) nghành dâ
# (ỹ) việc vặt, v
# (c) ch
# (c) ng
# (c) (t
# (a) thơ
# (u) màng đ
# (ờ)
#
# (c) đị
# (u) màng t
# (t)
#
# (ữ)
#
# (c) quạ chân
# (c) sự lừa
# (c)
#
# (.)
#
# (.)
#
# (o) dầu t
# (c) áo
# (n)
#
# (c) đạ
# (2)
#
# (2)
#
# (c) crom
# (c) mà
# (c) chất nhiễ
# (c) ph
# (c) crom
# (c) crom
# (c) th
# (c) lạp sắc
#
# (c) nhiễm thể
# (c) mạ
# (c) mạ
# (c) tí
# (c) ni
# (c) ni
# (o) đồng hồ bấm g
# (o) (thuộc) đồng
# (o) (thuộc) đồng
# (c) cây hoa c
# (á)
# (n)
#
# (i)
#
# (ổ)
#
# (c) khúc (
# (ỹ),  (thông tụ
# (i)
#
# (ờ)
#
# (c) ngư
# (c) ng
# (ơ)
#
# (c) dịch dưỡn
# (c) sự hoá th
# (c) sự hoá th
# (c) dịch sữa,
# (c) con ve sầ
# (c) vế
# (n)
#
# (n)
#
# (c) con ve sầ
# (a)
#
# (u) lông m
# (u) có lôn
# (c) có mao
#
# (c) thần
# (ỹ) nịt, đai da
# (c) cây canh-
# (o) đường chạy rả
# (t) hộp t
# (o) đường chạy rả
# (ỹ) tài tử xi n
# (ỹ) nữ tài tử x
# (ỹ),  (từ lóng)
# (c) th
# (ó)
# (c) Xơ
# (c) cây quế
#
# (c) cây ỷ lăn
# (c) cây ỷ lăn
# (e)
#
# (c) hình thoa
# (c) (viết
# (c) cái n
# (n)
#
# (à)
#
# (.)
#
# (.)
#
# (y)
#
# (.)
#
# (ì)
#
# (c) vòng
# (c) đư
# (ư)
# (i)
#
# (.) bằng đườ
# (c) sự xoay x
# (c) sự vẽ
# (c) xây
# (c) sự
# (i)
# (i)
# (a) trư
# (c) bệ
# (c) tua cuốn
#
# (c) có tua cu
# (c) loài chân
# (c) loài chân
# (c) tua cuốn
#
# (c) đường
# (ỹ),  (từ lóng)
# (ử)
#
# (à)
#
# (c) xitr
# (c) cây thanh
# (c) cây xả
#
# (c) giống cam
# (c) con cầy h
# (c) cô
# (c) cô
# (ố)
#
# (i)
#
# (g) ngườ
# (g) ngườ
# (.)
#
# (ỹ), (Uc) người
# (ỹ), (Uc) người
# (.)
#
# (c) con trai
# (.)
#
# (.)
#
# (i)
#
# (.); tiếng c
# (.)
#
# (c) th
# (h)
#
# (.)
#
# (g)
#
# (c) clar
# (ự) kèn
#
# (c) clar
# (.)
#
# (g) ưu t
# (t) (thuộc) mảnh
# (c) mệnh đề
#
# (c) hình chuỳ
# (c) clav
# (u) xương
# (c) hình chuỳ
# (m)
#
# (t)
#
# (c) gươ
# (ự) mìn
# (h)
#
# (.)
#
# (a)
#
# (.)
#
# (.)
#
# (o)
#
# (i) cọc đ
# (c) chìa
# (c) thụ tinh
# (c) cây ông l
# (h) l
# (h)
#
# (h)
#
# (c) cô
# (c) ng
# (c) con bổ củ
# (n) người
# (.)
#
# (.)
#
# (n)
#
# (c) cali
# (m)
#
# (c) theo
# (c) kh
# (c) kh
# (c) phép
# (u) móc l
# (a) vùn
# (h)
#
# (.)
#
# (c) bu
# (g) nhà
# (g) đặc
# (t) Fonolit
#
# (.)
#
# (c) cô bán
# (u) âm vật
# (t)
#
# (ỹ),  (từ lóng)
# (h) chụp c
# (à)
# (g) cl
# (y)
#
# (c) tu
# (c) dòng vô t
# (c) ch
# (i)
#
# (a)
#
# (c)
#
# (t)
#
# (o)
#
# (i)
#
# (h) cảnh
# (g)
#
# (p)
#
# (i)
#
# (g) old
# (o)
#
# (.), tiết mục được chú
# (á)
#
# (c) cây đinh
# (c) cỏ ba lá
#
# (n) & (nghĩ
# (g) cl
# (c) cây thạch
# (n)
#
# (y)
#
# (c) hình khiê
# (ý) ngườ
# (t) của co
# (c) sự
# (c) hợ
# (ị)
#
# (ý) ngườ
# (c)
#
# (e) (đị
# (c) giọt tụ,
# (g) bốn
# (.)
#
# (o) trợ l
# (ỏ)
#
# (t) điệp chứa th
# (ỹ) parafin
#
# (ò)
#
# (a)
#
# (y)
#
# (c) th
# (.)
#
# (i)
#
# (n)
#
# (c) bờ
# (g)
#
# (c) đồng
# (c) đồng
# (c) sự đồ
# (c) coba
# (c) co
# (c) co
# (c)
# (.) bằng
# (c) rắn mang
# (c) cây côca
#
# (ỹ) côca-côla (
# (u) xương
# (u) xương
# (n)
#
# (u) ốc tai
# (u) ốc tai
# (y)
#
# (g) mắt
# (g) lác
# (ổ) ngựa gỗ (tr
# (c) gác sá
# (a)
#
# (g)
#
# (c) anh ch
# (c) vẹt mào
#
# (i)
#
# (c) con bọ da
# (g) + u
# (c) sò
#
# (c) con gián
#
# (t) ca
# (c) cây dừa
#
# (c) cây dừa
#
# (c) cây dừa
#
# (c) đoạn
# (c)
#
# (c) côđêi
# (.)
#
# (c) người kỳ
# (.)
#
# (t) của co
# (c),  (vậ
# (c) cá vây ta
# (c) ngành độn
# (c) (thuộc) t
# (o) người
# (i)
#
# (ỹ),  (từ lóng)
# (n)
#
# (c) cây cà ph
# (n)
#
# (t) răng;
# (t) bánh
# (n)
#
# (.)
#
# (u) những
# (t) có
# (c) nhận t
# (c) nhận t
# (c) có thể
# (c) nhận t
# (c) có thể
# (g)
#
# (g)
#
# (ô) cô
# (c) đội
# (t)
# (ì)
#
# (i); tiền
#
# (u)
#
# (g) co
# (g) co
# (ỹ),  (thông tụ
# (t) đèo
#
# (t) của c
# (p)
#
# (t) dao t
# (t)
#
# (h)
#
# (ủ) để đánh thức dậ
# (.)
#
# (t) rèn n
# (i) để
# (i), hờ
# (m)
#
# (c) cải dầu
#
# (ỹ) xà lách cải
# (c) bộ cánh c
# (c) có cánh c
# (c) cơ
# (c) vi
# (t)
#
# (à)
#
# (u) xương
# (c)
#
# (à)
#
# (à)
#
# (i)
#
# (h)
#
# (.)
#
# (c) tr
# (t)
#
# (c)
#
# (ý) chu
# (ý) sự
# (ý) ống
# (i)
#
# (i)
#
# (c) ch
# (i)
#
# (ổ) cấu kết, th
# (t)
#
# (c);(đùa c
# (c) hình tràn
# (ự) đại
# (ự) chức
# (ự) hàm
# (ổ)
#
# (ỹ) (như) colou
# (c) nét
# (ỹ) truyền hình
# (c) mù
# (c) ch
# (.)
#
# (t)
#
# (.)
#
# (h)
#
# (n) & (nghĩ
# (c) cây cải d
# (c) sự
# (c) sự
# (c) hô
# (ỹ),  (quân sự)
# (ỹ),  (quân sự)
# (i), thung lũ
# (t) người c
# (h)
#
# (.) ((cũng) combin
# (t)
#
# (p) côngbin,
# (n)
#
# (t) máy chả
# (c) sự xoa
# (.)
#
# (c) mụ
# (c) mụ
# (c)
#
# (c) sa
# (c) sa
# (c) sa
# (ỹ),  (thông tụ
# (ỹ),  (thông tụ
# (ỹ) nhà vệ sinh
# (c) (như)
# (6)
#
# (á)
#
# (á)
#
# (g) Co
# (ự) xe c
# (.)
#
# (o)
#
# (h) cùn
# (c) bu
# (o) sự đe
# (u)
#
# (i)
# (c)
#
# (c) uỷ
# (ự) cục
# (n)
#
# (ư)
# (g)
#
# (t) ((cũng) seni
# (t)
#
# (ổ) phúc lợi ch
# (c)
#
# (ư)
# (g) Co
# (.)
#
# (ỹ) quỹ cứu tế
# (ỹ) vé tháng
#
# (ỹ) người đi là
# (c) có mào lô
# (c) (như)
# (ý)
#
# (h) so,
# (.)
#
# (g) a
# (m)
#
# (g)
#
# (h) hợp
# (c) đồ
# (c))
#
# (i); vật đ
# (.)
#
# (o) buổi
# (o) buổi
# (h) xứn
# (n) máy s
# (n) buồng
# (n) khung
# (n) thợ s
# (c) hợp
# (c) gạ
# (t) máy n
# (.)
#
# (c) thuyết
# (c) người
# (c) pian
# (h) sự
# (c) đàn
# (c) công
# (.)
#
# (m) c
# (m) c
# (c) ốc xà cừ
#
# (u) loa ta
# (c) có vỏ (ốc
# (c) conco
# (g) ngườ
# (n)
#
# (n)
#
# (n)
#
# (g)
#
# (.); bế mạc (p
# (c) đồng màu
#
# (h) hợp
# (c)
#
# (c) sự liên t
# (g); tính
# (g); có th
# (c); sự ng
# (c); làm n
# (ý) bìn
# (ù)
#
# (ư)
# (h) chi
# (i)
#
# (h)
#
# (c) kền kền k
# (g)
#
# (ý) độ
# (ý) tín
# (ý) có
# (ý) sự
# (ý) dẫn
# (ý) tín
# (c) gập đôi (
# (u) cục lõ
# (ỹ) con thỏ
#
# (c) câu ch
# (è)
#
# (ỹ) trò bội tín
# (ỹ) trò bội tín
# (p)
#
# (g)
#
# (o) l
# (o) người
# (h) sự phù h
# (c) quá ch
# (ẽ)
#
# (ỹ) (viết tắt)
# (c) cùng giốn
# (c) cùng giốn
# (g) co
# (.)
#
# (.)
#
# (c) su
# (ồ); dín
# (c)
#
# (c) đạ
# (a)
#
# (a)
#
# (c) hì
# (c) cây loại
# (c) có quả nó
# (c) vợ
# (t)
#
# (c); người liên
# (u) màng k
# (c) vi
# (g) mũi
#
# (ó)
# (ỹ) điều khiễn,
# (.)
#
# (n)
#
# (ỹ),  (từ lóng)
# (c) thông đồn
# (c) chụm lại,
# (ừ)
#
# (c) hô
# (m) (như) conscript
# (c) liên ứng
#
# (.)
#
# (y)
#
# (á); gửi (hàng
# (g) đ
# (á); sự g
# (f) g
# (ư)
# (h) phù
# (o) hội đ
# (ô) đứ
# (o)
# (t) của co
# (t) của co
# (c) sự t
# (c) thuậ
# (c) (thuộc) p
# (a)
#
# (m) làm nhục, lăng
# (c) cả
# (c); (vật
# (c) là
# (c) bị
# (c) ch
# (.)
#
# (ử)
#
# (c) hi
# (i)
#
# (u) cơ co
# (.)
#
# (c) sự
# (u)
#
# (u)
#
# (o) thuyế
# (c) tậ
# (c) lã
# (a)
#
# (.)
#
# (.)
#
# (c) sự
# (i) khoản
# (ý) cái
# (n) & (nghĩ
# (n) & (nghĩ
# (.)
#
# (ị) chính
# (c) khin
# (c) ngườ
# (h) cùn
# (c) văn
# (c) vă
# (.); láng giềng, bên
# (c) lụ
# (c)
#
# (c) xát (phụ
# (t)
#
# (u)
#
# (ỹ) máy bay cườ
# (.)
#
# (n)
#
# (c) công
# (c) công
# (ợ)
#
# (c)
#
# (c) sự
# (u)
#
# (c) giọn
# (t) cánh
# (c) đối
# (c) ngườ
# (n)
#
# (ổ) trái ý, trá
# (a)
#
# (h)
#
# (y); chiến hào bao vây
#
# (c) phản
# (m)
#
# (y)
# (y)
#
# (.)
#
# (c) sự
# (ố)
#
# (m)
#
# (m)
#
# (m)
#
# (c) giống quâ
# (ý) sự
# (ý) đối
# (.), họp, nh
# (ị); sự tr
# (c) nữ
# (c); (vật
# (ý); (t
# (ý); (t
# (h)
#
# (c) sự
# (o)
#
# (t) lò ch
# (c),  (vậ
# (n) tài s
# (ý) việc
# (g)
#
# (c) yế
# (n) & (nghĩ
# (ỹ) con thỏ
#
# (ỹ) (như) cooke
# (i)
#
# (ỹ) bếp, phòng
# (ỹ) lò, bếp lò
#
# (t) bá
# (ư)
# (t) chất
# (i), thung lũ
# (c) gấu trúc
# (i) ((cũng) coper)
#
# (c) chim sâm
# (ự),  (t
# (ý) sự t
# (ý) ngườ
# (h)
# (o) áo lễ
# (ư)
# (p)
#
# (g) ho
# (c) mái tư
# (c) đá mái
# (g) cảnh
# (ỷ)
#
# (c) sắt
# (c) rắn hổ ma
# (ỹ)
# (c) đồ
# (m)
#
# (.)
#
# (ư)
# (c) máy ba
# (c) sự nối
#
# (u) để gia
# (ỹ) người đọc b
# (.)
#
# (c) cây côkit
# (u)
#
# (c) tảo san h
# (c) tay đỡ
# (t) co
# (i) thừng
# (g)
#
# (i)
#
# (ổ) da đóng già
# (ổ) thợ đóng gi
# (.)
#
# (c) cây phòng
# (ả)
#
# (u)
#
# (g) cái
# (à)
#
# (c) thân hành
# (c) chim cốc
#
# (n)
#
# (c) (thuộc) h
# (u) màng s
# (u) (thuộc
# (c) giống cây
# (t) cacnelia
# (.)
#
# (g) co
# (o) cờ (cắm ở) gó
# (ư)
# (ở
# (c) kèn
# (c) gờ; má
# (c) kèn
# (ú)
#
# (n)
#
# (c) tràng
# (c) hệ lu
# (c) tán mặt tr
# (n)
#
# (c) tán mặt tr
# (u)
#
# (u) hình v
# (c),  (động v
# (c),  (động v
# (ý) nhân
# (u) vẹt hì
# (c) dừa ngà (
# (o) khăn
# (c) đo
# (c) đo
# (ý) cụ t
# (ự) quân
# (ỹ),  (quân sự)
# (c) ti
# (ỹ) ràn, bãi qu
# (í)
#
# (a)
#
# (i)
#
# (h)
#
# (h)
#
# (i);
# (c)
#
# (.)
#
# (c)
#
# (n) & (nghĩ
# (à)
#
# (ổ),  (thơ ca)
# (c) áo
# (à)
#
# (c) áo
# (a)
#
# (u) vỏ
#
# (c) (thuộc) v
# (u) vỏ
#
# (c) cooct
# (t) corunđum
# (i) tàu h
# (c) co
# (c) ngù (một
# (ê)
#
# (c) ch
# (g) Co
# (c) cosec
# (g) cái
# (c) cosin
# (c), (thuộc)
# (c) vũ
# (c) kh
# (c) kh
# (c) vũ
# (c) vũ
# (c) kh
# (c) kh
# (c) to
# (c) to
# (u) (thuộc
# (ỏ) dò hư
# (.)
#
# (.)
#
# (ỏ)
#
# (c) cotan
# (i)
#
# (t) nô
# (ư)
# (.); bông
#
# (n)
#
# (n)
#
# (c) thỏ đuôi
#
# (c) bô
# (c) lá mầm
#
# (u) hình c
# (c) cỏ băng
#
# (u)
#
# (a)
#
# (c) loài báo
# (c)
#
# (u) hậu t
# (t) hẻm
#
# (c) culôn
# (c) cái đ
# (c) cái đ
# (p) dao cày
#
# (ỹ) hội viên hộ
# (h) ((xem) earl)
#
# (.)
#
# (h)
#
# (ự) luỹ
# (c) th
# (c) người
# (.)
#
# (u)
#
# (.); biện
# (c) đối
# (c)
#
# (n)
#
# (ỹ) (như) count
# (ỹ) câu lạc bộ
# (n)
#
# (n)
#
# (h)
#
# (a) cặp
# (.)
#
# (o)
#
# (o) cuộc săn thỏ
#
# (à)
#
# (J)
#
# (ọ); a
# (t) vịnh nhỏ, vũ
# (.)
#
# (ự) ném
# (ự) ném
# (.)
#
# (ỹ) cái gạt vật
# (c) lợn biển;
# (c) thú y
# (c) đậ
# (ỹ) (thông tục)
# (.)
#
# (u)
#
# (c) ốc tiền
#
# (c) cây anh t
# (n)
#
# (c) há
# (c) há
# (c) chó sói đ
# (c) sự l
# (g) cr
# (c) cừ, xu
# (c) khó đọ
# (ỹ) bánh quy gi
# (t) crack
# (ỹ),  (từ lóng)
# (ư)
# (g)
#
# (g)
#
# (c) gà nước
#
# (n)
#
# (h)
#
# (c) ch
# (g) cr
# (ữ)
#
# (g)
#
# (c) con sếu
#
# (u) sọ
#
# (u) (thuộc
# (u) sọ
#
# (ỹ) trò chơi sú
# (.)
#
# (i) lái mô
# (g) hạ cánh
# (c) (thuộc) h
# (i)
#
# (n); sọt (để đựng đồ sứ, hoa quả...)
#
# (ọ)
#
# (ư)
# (c) loài bò s
# (c) thấy s
# (u) lồi cầ
# (a)
#
# (ể)
# (ể)
# (.)
#
# (.), kh
# (i); sự s
# (u) sự gh
# (i)
#
# (c),
# (c),
# (c);
# (c);
# (c);
# (c);
# (c) khía tai
# (c) khía tai
# (h)
#
# (h)
#
# (g) cr
# (c) creo
# (u) sự gh
# (c) ho
# (c) mạnh
# (c) cải xoong
# (à)
# (t) có phấn trắn
# (c) ng
# (c) ch
# (c) độ
# (.)
#
# (g)
#
# (á)
#
# (g)
#
# (u)
#
# (n)
#
# (c) có lỗ rây
# (u) hình c
# (.)
#
# (.)
#
# (c) con dế
#
# (c) tộ
# (c) tộ
# (i) vòng
# (c) có lông
#
# (ệ)
#
# (i); kêu
# (g) ốm y
# (c) giống ngh
# (t) ch
# (c) đá vòng
# (n)
#
# (o) crôkê, bóng v
# (n)
# (c)
#
# (a); đài thập ác (đài kỷ niệm trên có chữ thập)
#
# (h)
#
# (ý) sự k
# (t) thanh
# (t) xà ng
# (o)
#
# (i)
#
# (c) lá
# (ỗ)
# (ỗ)
# (.)
#
# (ư)
# (o) ((cũng) cr
# (i)
#
# (c) giao phấn
# (c) sự giao p
# (u)
#
# (p); câu chuyện
# (n)
#
# (g) in t
# (t) đòn n
# (y)
#
# (n)
#
# (c) bệ
# (c) bệ
# (c)
#
# (t)
#
# (t)
#
# (i) chòi
# (c) cá
# (t)
#
# (c)
#
# (c) hình chữ
# (i) vào gi
# (i) vào gi
# (n)
#
# (ỷ)
#
# (i) tàu t
# (t) cá
# (ỹ) bánh ca vát
# (g) mập
# (.)
#
# (i)
#
# (c) cuộ
# (c) tha
# (ổ) bình (bằng)
# (ỉ)
#
# (á)
# (c) (thuộc) l
# (g) pair
# (n)
#
# (.)
#
# (t) criolit
#
# (c) hỗn
# (c) phép
# (ờ)
#
# (c) đảng v
# (c) cây không
# (c) không hoa
# (c) không hoa
# (c) mậ
# (c) mậ
# (g) t
# (c) hình lược
# (.)
#
# (c) Cu
# (g) cubb
# (c) hình
# (.)
#
# (a) xu h
# (2)
#
# (u) (thuộc
# (c) chim cu c
# (c) cây chân
# (c) cây dưa c
# (c) loại cây
# (c) (thuộc) h
# (i)
#
# (u) vĩ bạ
# (t); cổ tay
# (c) giá
# (c) giá
# (c) nấ
# (p)
#
# (i)
#
# (g) anh
# (.)
#
# (g) cu
# (c) vă
# (g) cu
# (c) bồ câu rừ
# (c) cây thìa
# (t) mẹ
# (n) khă
# (c) cây thìa
# (o) cuộc đấu loại
# (n), tủ
# (.)
#
# (c) thần ái tình
#
# (à)
#
# (g) chén
# (c) sự
# (c) ốn
# (c) (thu
# (c) (thu
# (c) quả đấu
#
# (u)
#
# (.)
#
# (o) chức
# (n) (của người da đ
# (o) cha p
# (.)
#
# (a)
#
# (c) cây nghệ
#
# (t)
#
# (n)
#
# (.)
#
# (c) sự
# (c) th
# (t), đồ cổ
#
# (c) curi
# (c) chim mỏ n
# (t) mô
# (g) nói
# (c);
# (c)
#
# (h)
#
# (m)
#
# (ư)
# (ợ) lúc thanh
# (ự) lưới
# (n)
#
# (ữ)
#
# (ữ)
#
# (g)
#
# (a)
#
# (c) đư
# (c) có gân co
# (c) có mỏ con
# (i
# (p)
#
# (g) dễ c
# (.)
#
# (c) có đi
# (ỹ) ống nhổ
#
# (ỹ),  (từ lóng)
# (ỹ),  (thông tụ
# (ỹ),  (thông tụ
# (c) cây na
#
# (.); đóng đ
# (.)
#
# (c) da
# (c) cô ả x
# (i) thanh
# (.), sự
# (ỹ),  (từ lóng)
# (c) sâu ngài
# (c) xyan
# (c) xyan
# (c) ch
# (ý) điề
# (c) cây mè
#
# (c) cây hoa a
# (ý) chu
# (h)
#
# (ỹ) (như) cycli
# (c) xyclo
# (y)
#
# (c) ng
# (p)
#
# (p)
#
# (ý) xyc
# (c) trụ,
# (c) cái
# (c) ngườ
# (c) xim (kiểu
# (ô) má
# (c) (t
# (c) (t
# (c) cây bách
#
# (c) túi bao,
# (c) tú
# (c) xyst
# (c) vi
# (c) tế bào họ
# (c) vua
# (c) hoà
# (c) Sé
# (c) Ti
# (c) Sé
# (ã)
#
# (4) trong đại chiến II)
#
# (ỹ),  (quân sự)
# (c) (như)
# (c);
# (c) chim lặn
#
# (c) cá đác (h
# (c) chó chồn
# (n) giặ
# (n) sự
# (a) Đac
# (c) đa
# (g)
#
# (c) ngôn ngữ
# (c) ba, ch
# (c) ba, ch
# (.)
#
# (c) con chôm
# (ư)
# (ổ) gạt, bỏ
#
# (c) cây thuỷ
# (c) cây thuỷ
# (c) cây thuỷ
# (ỹ),  (thông tụ
# (ỹ) agô
#
# (c) cây thược
# (n)
#
# (c) cây cúc
#
# (h)
#
# (h)
#
# (i)
#
# (c) mù
# (c) ch
# (c) vật mẹ
#
# (t) công
# (c) con đaman
# (i)
#
# (.)
#
# (g)
#
# (ý) sự g
# (ý) gây
# (ổ); (thơ ca) c
# (c) cây mận t
# (i)
#
# (ỹ) tiệm nhảy
#
# (c) cây bồ cô
# (ỹ),  (thông tụ
# (i); mặ
# (i)
#
# (u)
#
# (n) cái
# (i) bán
# (c) bệ
# (t) tín hiệu "ng
# (h)
#
# (c) Đa
# (g)
#
# (c) cây thuỵ
# (g) xích
# (h)
#
# (i)
#
# (c) người
# (a) tối
# (c) người
# (c) cỏ lồng v
# (.)
#
# (c) bệ
# (c) họ
# (.)
#
# (c) cây chà l
# (c) (thuộc) t
# (.); điều đã
# (u)
#
# (c) cây cà độ
# (.) trát tường; lớp trát bên ng
# (ẽ)
#
# (c) đạ
# (i) cần t
# (g) to t
# (i),  (từ
# (ỏ)
#
# (c) quạ gáy x
# (n)
#
# (y)
#
# (c) qu
# (c) ch
# (n) sổ n
# (c) con phù d
# (c) cây hoa h
# (y)
#
# (a) bìn
# (g) sự công
# (.)
#
# (t) mica
#
# (n) & (nghĩ
# (c)
#
# (c) lo
# (g) thiết b
# (o) người
# (o) bà tr
# (o) chức
# (i)
#
# (t) điểm
# (ạ)
#
# (h)
#
# (ự) khu
# (o) tình trạng cù
# (c)
#
# (c) khúc
# (c)
#
# (ô) vù
# (c) tường
# (.)
#
# (c) mệt lử
# (c) cây tầm m
# (ỹ),  (từ lóng)
# (t) điểm
# (i) sức c
# (i) gió n
# (ỹ) cái bẫy
#
# (g) sự bế t
# (c) cây cà dư
# (t) máy t
# (c)
#
# (g) dùng
# (g) dùng
# (c)
#
# (i)
#
# (o) lấy ở mặt n
# (.)
#
# (c) ch
# (ỹ) (viết tắt)
# (á) lên b
# (n)
#
# (ể)
#
# (.)
#
# (.)
#
# (h) xuống
#
# (ự) điểm
# (c) hình
# (c) (thuộ
# (c) (thuộ
# (c) khối
# (.)
#
# (ỹ) đêcalit
#
# (ỹ) đêcalit
#
# (o) mười
# (c) có mười n
# (c) tr
# (g)
#
# (.)
#
# (c) có mười l
# (c) giáp xác
# (c) khử
# (c) khử
# (g) theo l
# (g) theo l
# (o) cuộc thi mười
# (.)
#
# (ỹ) người đã ch
# (c) th
# (c) ngư
# (ị) phân q
# (ị) sự phâ
# (ị) phân q
# (ý) làm
# (c) rụng vào
# (e)
# (c) thập
# (ã)
# (ã)
# (ã)
# (.); sự phân x
# (g) sự hạ x
# (g)
#
# (y)
#
# (y)
#
# (.)
#
# (ý) ngườ
# (ư)
# (c) có thể bi
# (ý) cái
# (ý) cái
# (t) nhả s
# (.)
#
# (.)
#
# (ã), gi
# (c) sự
# (ý); (h
# (ý); (h
# (ý),  (
# (ư)
# (.)
#
# (.)
#
# (a),
# (i)
#
# (.)
#
# (ự),  (h
# (.)
#
# (c) nhẹ
# (c) sắ
# (c) sắ
# (g)
#
# (t)
#
# (ớ)
#
# (i)
#
# (h)
#
# (t)
#
# (c) hươu, nai
# (i)
#
# (i)
#
# (a)
#
# (c)
#
# (ý) ngườ
# (ý) sự h
# (ý) có t
# (.); sự tiêu tan (hy
# (n) & (nghĩ
# (o) sự bỏ
# (o) kẻ bỏ
# (ý) ngườ
# (ỹ) (như) defen
# (c) để dẫn
#
# (.)
#
# (c) sự
# (h) số tiề
# (n) & (nghĩ
# (.)
#
# (ý) bộ
# (c) rụng hết
# (c) làm rụng
# (c) sự làm rụ
# (i)
#
# (.)
#
# (.)
#
# (.)
#
# (o) bắt b
# (i) giải
# (ự) lột
# (ế)
#
# (c) nẻ ra, nứ
# (c) sự nẻ ra,
# (c) chất
# (c) loại
# (c) sự l
# (c) sự l
# (c) loại
# (c); (ngôn
# (c) th
# (c) th
# (t)
#
# (g) cái
# (n) dấu b
# (h)
#
# (n)
#
# (n)
#
# (n)
#
# (ý) sự p
# (.); vạc
# (c) tì
# (c) ch
# (c) tr
# (c) âm
# (m) cứu
# (m) sự
# (ư);
# (p) phiếu giao
# (i)
#
# (i); kh
# (c) Đe
# (c) Đe
# (c) cây la lế
# (p)
#
# (c) ch
# (ỹ) (như) demag
# (ý) ngườ
# (c) ch
# (ủ)
#
# (y)
#
# (.)
#
# (c) sự
# (c) kh
# (c) nốt
# (ý) sự c
# (c) nốt
# (c) đấng t
# (g) (như
# (c) lính g
# (c) nh
# (ệ)
#
# (ệ)
#
# (ệ)
#
# (ư)
# (p)
#
# (a)
#
# (c) là
# (i) sự gi
# (ý) sự b
# (ơ)
#
# (ữ); sà
# (ã)
#
# (c) hệ
# (g) hì
# (t)
#
# (t)
#
# (t)
#
# (t)
#
# (ổ) sự từ chối,
# (c) bệ
# (i)
# (c) loại
# (c) loại
# (c) gi
# (c) mẫu s
# (ý) cái
# (h)
#
# (c) ră
# (c) có răng
#
# (c) khe răng
# (u) ngà ră
# (.); tình trạng trần
# (.); làm trần trụi, l
# (c) đạ
# (c) kh
# (c) khử,
# (c) sự k
# (c) sự k
# (c) khử,
# (c) chất
# (c) loại
# (c) sự l
# (.)
#
# (n) phụ thuộ
# (c)
#
# (c)
#
# (ý) làm
# (ý) sự
# (c) loại
# (c) sự l
# (c) loại
# (ư)
# (g) xuồng m
# (ự) sự d
# (ự) sự d
# (ý) khử
# (ý) sự
# (ý) khử
# (ý) chấ
# (ý) làm
# (ý) ngườ
# (.); hạ
# (.); sự
# (g)
#
# (n) & (nghĩ
# (g) de
# (g) số n
# (c) th
# (o); thay
# (o); thay
# (.)
#
# (.)
#
# (.)
#
# (.)
#
# (0) ((cũng) derby day)
#
# (m),  (như) derisiv
# (ừ); sự
# (u) da
#
# (u) da
#
# (c) da
# (c) vi
# (c) th
# (c) kh
# (u) sự cấy
# (c) bệ
# (c) da
# (ỹ),  (như) dar
# (.); sự bị xúc phạm (uy tí
# (.); không xứng với (phẩm giá, địa vị...
# (c) giống cây
# (.)
#
# (m),  (như) descend
# (.)
#
# (t), sự bá
# (t), kẻ bá
# (ỹ) xoá bỏ sự p
# (c)
#
# (.), người trang t
# (t) b
# (t) b
# (i)
#
# (.); sự sai phái đi
# (n)
# (c) ngự
# (c) loại
# (c) sự l
# (c) loại
# (.)
#
# (t) cái h
# (.); tẩy
#
# (ã)
# (c) thuyết
# (c) sự
# (c) để
# (.)
#
# (c) sự t
# (ý) sự c
# (c) giả
# (c) giả
# (t) (thuộc) vật
# (.); mảnh vụn
#
# (ỹ) dỡ (hàng) ở
# (ô) là
# (c); quân bà
# (c) đơte
# (c) đơte
# (ệ)
#
# (ệ)
#
# (ệ)
#
# (ệ)
#
# (.)
#
# (c) có th
# (h) người
# (.)
#
# (g) sai đườ
# (g) sự sai
# (ị) tác ph
# (ị) người
# (c) quân s
# (c) quân b
# (ỹ) con chuồn c
# (y); sự giậm c
# (c) cá đuối h
# (c) cây hoa m
# (ư)
#
# (ý) ngườ
# (ý) ngườ
# (h)
#
# (h)
#
# (c) làm mất t
# (c) làm mất t
# (.)
#
# (t) (thuộc) kỷ đ
# (a)
#
# (c) quả mâm x
# (c) đext
# (c) quay
# (c) quay
# (c) quấn phải
# (c) đext
# (n) chó
# (n) cái
# (n)
#
# (ộ) (d
# (ộ) (d
# (t) điaba
#
# (c) bệ
# (c) (t
# (c) ma
# (c) ma
# (c) lịch lại
#
# (c) lịch lại
#
# (c) th
# (c) th
# (c) th
# (o) trợ t
# (c) diacritic
# (c) diacritic
# (c) hai bó, x
# (c) dấu tách
# (c) dấu tách
# (c) ch
# (c) ph
# (c) ph
# (c) ch
# (g)
#
# (c) bi
# (c) bi
# (ờ) ((cũng) sun dial)
#
# (c) ti
# (c) có t
# (c) thẩm
# (c) thẩm
# (c) thẩm
# (g)
#
# (c) đường
# (c) đường
# (c),  (nh
# (a)
#
# (c) nữ thần Đi-an (n
# (c) có hai nh
# (c) cây hoa c
# (c) tầm
# (c) mà
# (u) thân x
# (c) bệ
# (c) ỉa
# (c) ỉa
# (c) đias
# (c) đias
# (c) sự
# (ý) tín
# (c) ph
# (c) tạ
# (c) tạ
# (c) tảo cát
#
# (t) điatomit
#
# (t) điatomit
# (c) (thu
# (g)
#
# (c) chín khác
# (c) sự chín k
# (c) đicl
# (c) đicr
# (u)
#
# (c), ma, q
# (p), một chục,
# (c) cây hai l
# (c) có hai lá
# (g) số n
# (o)
#
# (i)
#
# (h)
#
# (c) chim lặn
#
# (g), lừa
# (c) điđi
# (c) chất
# (ý) ngày
# (ý) ngày
# (t) bàn r
# (g) di
# (h)
#
# (c) ch
# (c) ch
# (g) + fr
# (.)
#
# (.)
#
# (.)
#
# (ý) làm
# (ý) sự
# (ý) khu
# (g)
#
# (ý) máy
# (ý) khu
# (g)
#
# (t)
#
# (u) hai th
# (t)
#
# (g) digs)
# (p) cho
#
# (c) ng
# (c) đi
# (c) giống mao
# (c) phân ngón
# (c) đi bằng đ
# (n)
#
# (.)
#
# (t)
#
# (t)
#
# (g) sự đ
# (c) nhị d
# (i)
#
# (.); là
# (à);
# (.); sự làm
# (u) cơ giã
# (ì)
#
# (c) cây thì l
# (y)
#
# (t) (thuộc) lũ t
# (t) lũ tích
#
# (g)
#
# (a)
#
# (ỹ) cửa hàng bá
# (c) nhị hợp
#
# (c) nhẹ
# (c) giảm nhẹ
#
# (c) giảm nhẹ
# (c) tính làm
# (.)
#
# (ư)
#
# (u)
#
# (g)
#
# (y)
#
# (c)
#
# (a)
#
# (c)
# (c) có duy
# (u)
#
# (n)
#
# (c) khủng giá
# (c) khủng điể
# (c) khủng lon
# (c) kh
# (c) khủng thú
# (c) gi
# (c) khác gốc
#
# (ý) điô
# (ý) điô
# (a) tran
# (a) (thu
# (t) điorit
#
# (c) điox
# (.)
#
# (c) hai cánh
# (c) hai p
# (ư)
# (c) ch
# (c) (t
# (ý) hai
# (ý) lưỡ
# (ọ)
#
# (c) có hai
# (ọ)
#
# (c) bệ
# (c) (t
# (c) bạ
# (c) bạ
# (c) bệ
# (i)
# (g) r
# (c) gi
# (g) di
# (c) đường
# (c) đường
# (ễ) mai t
# (ý) bãi
# (t)
#
# (.)
#
# (ì)
#
# (i)
#
# (i)
#
# (c)
#
# (c)
#
# (i); là
# (t) tháo
# (c) sự dị hoà
# (m) phâ
# (.)
#
# (ý)
#
# (y)
#
# (ý) sự t
# (.)
#
# (ý) khai
# (ô)
#
# (o) đĩa
#
# (u)
#
# (u)
#
# (u)
#
# (.)
#
# (g)
#
# (ĩ)
#
# (ỹ) lính giải n
# (g)
#
# (o) đĩa
#
# (c) kỷ
# (c) kỷ
# (c) mô
# (.)
#
# (i)
#
# (i)
#
# (a); tượng
# (a); tượng
# (h)
#
# (g)
#
# (ư)
# (.)
#
# (.); tình tr
# (t)
#
# (h); nhận thanh toán (hối phiếu,
# (ý) chưa
# (i)
#
# (.)
#
# (c) biệt
# (m) phâ
# (o) đĩa
#
# (ì); nói đến (
# (h) lên bờ,
# (.) lên
# (f) l
# (.) lìa
# (.) lìa
# (g)
#
# (.); dốc bầu
# (ờ)
#
# (o) miếng gỡ đườn
# (i) đào
# (n)
#
# (g)
#
# (c)
#
# (.)
#
# (n)
#
# (o) đĩa
#
# (p) bừa đĩa
#
# (.)
#
# (.)
#
# (.)
#
# (.)
#
# (.)
#
# (.)
#
# (.)
#
# (m),  (như) dismiss
# (.)
#
# (i), là
# (i), là
# (n) & (nghĩ
# (n) & (nghĩ
# (n) & (nghĩ
# (.); sự sai phái đi
# (o) túi thư
# (ự) chó
# (ự) ngườ
# (t) trạm gửi (hà
# (n)
#
# (ý) chấ
# (c) thể
# (n) ((thường) (viết tắt) D.P.)
#
# (n) & (nghĩ
# (.)
#
# (.)
#
# (g) + of
# (.); sự chứng minh là sai
#
# (.); chứng minh là sai; nhân chứng
# (.)
#
# (i) giáng
# (g) không nhớ lại
# (a)
#
# (f) t
# (f) t
# (.)
#
# (.); phổ biến
#
# (o) người
# (c) vách, vác
# (i)
# (c) làm cho k
# (c)
#
# (.)
#
# (.)
#
# (m) phâ
# (c) sự n
# (c) nghị
# (t) con qua
# (u),  (thự
# (t) thanh
# (.); làm căn
# (c) (xếp thàn
# (c) phần
# (c) sự c
# (u)
#
# (g) di
# (.); sự lãng trí, sự đãng trí; điều x
# (ý) tịch
# (ý) ngườ
# (ý) ngườ
# (ý) sự t
# (ý) ngườ
# (ý) sự t
# (i) súng
# (i) pháo
# (ý) lệnh
# (ý) lệnh
# (o)
#
# (c) run lậ
# (c) th
# (c) cây bạch
# (i)
#
# (c) sự
# (c) lợ
# (ư)
#
# (c) hoá
# (c) có h
# (c) phân nhán
# (.); sự
# (ự) máy
# (ổ);(đùa cợt) n
# (h)
#
# (h) phú ông
# (ỹ) đường chia
# (c) số bị
# (i)
#
# (ỏ)
#
# (t) tả
# (ổ) để lộ ra, t
# (g) tiền
# (ự) nồi
# (ỹ) các bang mi
# (ỹ) các bang mi
# (ự) nồi
# (m) trang điểm, ăn
# (à)
#
# (c) thầy t
# (.)
#
# (c) giống cây
# (g)
#
# (ý) sổ g
# (g) thành
# (g) thành
# (n)
#
# (c) ti
# (c) ch
# (g)
#
# (c) tà
# (c) tà
# (c) hình
# (c) khối
# (c) dây tơ hồ
# (y)
#
# (.); động tá
# (c) chim cưu
# (c) chim cưu
# (c) chim cưu
# (ũ)
# (ở)
#
# (ở)
#
# (.)
#
# (c) cây bách
# (t) toa chở chó
#
# (m), tiết đại
# (ở)
#
# (ở)
#
# (ỹ) tranh giành
# (ó)
# (o) thế cùng ngã
# (c) cây cúc h
# (t) đinh
# (c) cá hồi ch
# (c),  (thông t
# (c) kiểu t
# (i) phiên
# (c) chó sói đ
# (c) chứ
# (ó)
#
# (c) tổn
# (ỹ),  (từ lóng)
# (n)
#
# (g); đành
# (g) do
# (i) giá đ
# (y)
#
# (.)
#
# (.)
#
# (t) lẫ
# (c) có đầu dài,
# (n) & (nghĩ
# (ỹ)
# (c) khúc t
# (ê)
#
# (ữ)
#
# (o) thuỷ thủ
#
# (c)
#
# (c) mộ đá
#
# (t) đolomit
#
# (a) đau
# (a) nỗi
# (c) cá heo mỏ
# (.)
#
# (c) đấ
# (c) vòm, m
# (c) gi
# (t)
#
# (.); th
# (.); sự
# (t)
#
# (.)
#
# (c) vò
# (c) vò
# (c) nh
# (o)
#
# (c) Ch
# (o) (thuộ
# (t) ôn
# (g)
#
# (g)
#
# (a)
#
# (ỹ) tặng, cho,
# (ổ)
#
# (t) tời h
# (a)
#
# (ỹ) con bọ cánh
# (n) cán
# (h)
#
# (o) ngày
# (.)
#
# (.)
#
# (ỹ) sân trước
#
# (ở
# (a)
#
# (a)
#
# (i)
#
# (ỹ) người dự đo
# (.)
#
# (.)
#
# (ỹ),  (như) dor
# (c) cá nục he
# (h)
#
# (n) & (nghĩ
# (c) chuột sóc
# (.)
#
# (c) chuột sóc
# (ỹ),  (từ lóng)
# (ữ)
#
# (u) (thuộc
# (n)
#
# (n)
#
# (c) cá dây gư
# (g)
#
# (g) giườ
# (g) nhà
# (ọ)
#
# (à)
#
# (à)
#
# (à)
#
# (à)
#
# (u)
#
# (c) chim choi
# (u)
#
# (c) chim choi
# (p) kế toán ké
# (g) cuộc số
# (t) tác đ
# (ô)
#
# (g)
#
# (c) công
# (ủ)
#
# (i) quấn
# (o)
# (c) hai m
# (ỹ),  (từ lóng)
# (.)
#
# (i)
#
# (ỹ) xe lửa hai
# (n) cách
# (i)
#
# (g)
#
# (c) áo
# (i)
#
# (c) đồn
# (.)
#
# (t) nh
# (ỹ) người nhu n
# (ổ);(đùa cợt) s
# (ổ);(đùa cợt) d
# (o)
#
# (c) cây cọ đu
# (t) ng
# (i) hạ (b
# (c) giống pho
# (u)
#
# (c) mộng đ
# (n)
#
# (g)
#
# (.)
#
# (t) chốt
#
# (ợ)
#
# (t) gió l
# (.)
#
# (.); tr
# (h)
#
# (t) sự sụt lún
#
# (ỹ) thời gian c
# (ỹ) khu buôn bá
# (c) vù
# (h)
#
# (ò)
#
# (ỏ)
#
# (o) bài t
# (c); trưởng đoàn (
# (i)
#
# (ỹ),  (viết tắt
# (c) giống cây
# (t)
#
# (p)
#
# (.)
#
# (ỹ),  (quân sự)
# (ỹ),  (quân sự)
# (ỹ),  (quân sự)
# (ỹ) lính quân d
# (.)
#
# (.)
#
# (e)
#
# (.)
#
# (.)
#
# (t) dây k
# (ư)
#
# (ự) chôn
# (c) con chuồn
# (c) cây máu r
# (u) sự kh
# (ự) kỵ b
# (ỏ) người
# (g)
#
# (.), cốn
# (.)
#
# (c) quần b
# (c) ốn
# (ì)
#
# (m)
# (ư)
# (ổ)
# (ổ)
# (t)
# (.)
#
# (t)
#
# (.)
#
# (c) th
# (.)
#
# (y)
#
# (u)
#
# (ư)
# (t) bàn k
# (i)
#
# (p) người than
# (g)
#
# (y)
#
# (g) a
# (n)
#
# (t) máy k
# (t) cái b
# (t)
#
# (ẽ)
#
# (c)
#
# (o)
#
# (g)
#
# (g)
#
# (o); áo khoác bằng vải dày (mặc kh
# (.)
#
# (ơ)
#
# (g)
#
# (ổ) chịu đựng,
# (g) số n
# (t)
#
# (u) buổi
# (i)
#
# (i)
#
# (ữ)
#
# (i)
#
# (à)
#
# (ủ)
#
# (ự) trạm
# (ỹ) (cũng) dress
# (i)
#
# (o) cầu thủ rê bó
# (.); tình
# (.)
#
# (t) mũi k
# (ự) bài
# (ự) phòn
# (ự) hạ s
# (ế)
#
# (t) tí tá
# (t)
#
# (ỹ) quầy ăn phụ
# (n)
#
# (.), người đánh x
# (ỹ) đường lái x
# (t) trục
# (t) curoa
# (.)
#
# (t) bánh
# (t) bánh
# (i)
#
# (i)
#
# (ý) quyề
# (c) sân ba
# (c) lạc đà mộ
# (c) thu
# (c) ong mật đ
# ...
# (P) máy xử lý
# (ữ) cấu t
# (ữ) cụm t
# (ữ) cấu t
# (.)
#
# (g)
#
# (.)
#
# (.)
#
# (.)
#
# (c)
#
# (.)
#
# (s) giai cấp công
# (í))
#
# (a)
#
# (m) xứng
# (t)
#
# (e) số từ trên một phút
# (c)
#
# (c)
#
# (u)
#
# (i)
# (n)
#
# (a) Nhà Ngô (thời
# (d)
#
# (b)
#
# (g)
#
# (t)
#
# (m) cấm ngườ
# (D) c
# (e)
#
# (ỹ) tờ
# (á)
# (c)
#
# (n) kéo sợ
# (m)
#
# (á) thẻ
# (g) nhút
# (g)) thuốc phiện,
# (n)
#
# (c)
#
# (n)
#
# (e)
#
# (a) Nhà Nguyên (1
# (n)
#
# (ô)
#
# (a)
#
# (t) họ
# (p)
#
# (g)) nhà giàu kếc
# (ạ)
# (g)
#
# (ạ)
# (t) cây g
# (c) ư
# (c) đớ
# (c) bi
# (n)
# (t) thực
# (í) qua
# (ê) không
# (h) lối v
# (h) bộ tí
# (i) điểm một, mặt n
# (c) điểm
# (c) âm
# (í) âm
# (c) tí
# (ế) chuyên vi
# (g)
#
# (t) cộng t
# (h) điều
# (h) điều
# (ê) tính
# (ế) sự tổng h
# (c) đạ
# (c) th
# (ê) có độ
# (ê) phân
# (h) cho v
# (n) vĩ tuy
# (n) vĩ tuy
# (α
# (c) ch
# (g) loại
# (c) không
# (t) sự tắ
# (ế) thanh toá
# (í) máy
# (n) độ phư
# (h) máy p
# (c) gó
# (ố) lin
# (ế) niên khoả
# (ố) lin
# (i) mở (bài); tiền
# (c) tiền k
# (ố) dây
# (t) antim
# (ố) xuy
# (ố) sự
# (ố) đối
# (ê) chuỗi
# (n) đ
# (n) đ
# (n) điểm v
# (c) đỉ
# (n) viễn đ
# (h) a- điể
# (c); (thiên văn)
# (c) đi
# (c) di
# (c) di
# (c) số
# (h) mảng
#
# (ồ)
#
# (ê) sự th
# (n)
#
# (ế) tài sản;
# (ố) cái
# (;)
#
# (c) du
# (c) th
# (c) vậ
# (c) at
# (í) nhi
# (c) ng
# (h) điểm h
# (c) âm
# (h) số hạ
# (c) tr
# (c) ti
# (n) độ phư
# (c) gó
# (ế)cán cân th
# (t) bản l
# (g) c
# (c) dá
# (ế) lãi
#
# (i) đánh cuộc
#
# (β
# (ê) độ ch
# (ê) chệch
# (ế) ngân phiế
# ( ) (ở
# (c) nú
# (ê) sinh
# (ê) sinh
# (n) số nhị phân
#
# (m)
#
# (ê) hai c
# (í) màn
# (h) bảng,
# (n) sao bă
# (ê) sự bu
# (ô) bệ
# (t) cầu
#
# (í) sự
# (ế) ngân sách
# (h) bộ ph
# (h) đã lắ
# (ô) kh
# (ế) mua
#
# (ế) người mua
# (ô) ca
# (c) nh
# (c) cam
# (c) bộ
# (c) trụ
# (i), gạch
# (c) dầm
# (n);
# (ế) vốn, tư b
# (h) tấm b
# (s))
#
# (h) bàn t
# (g)
#
# (h) số ma
# (c) Đề
# (ế) tiền mặt
#
# (g)
#
# (c) ph
# (í) cat
# (c) ng
# (í) tín
# (í) nhâ
# (c) vũ
# (h); khối
# (c) tế
# (ỏ)
#
# (ê) làm t
# (ê) bị th
# (%
# (ê) bách
# (c) tr
# (ố) nhó
# (t); phỏng tâm
#
# (h) /
# (ố) đặc
# (ồ)
# (i) trò chơi cờ (tâ
# (i) quân bài năm
#
# (h) mạch,
# (c) mạ
# (c) đư
# (h) lưu số
# (x)=x )
#
# (à) liên thông Hauxd
# (c) cổ
# (ê) sự ph
# (h)
#
# (h)
#
# (t) răng
# (c) mã, chữ số;
# (a) khoản
# (ô) số
# (ê) thống
# (í) khá
# (ô) sự
# (ô) cù
# (ê) hiển
# (c) giống
# (ê) sự ch
# (í) sự
# (ô) đố
# (h) cuộn
# (ô) cù
# (ố) đối
# (n) phần p
# (ô) co
# (h) máy s
# (ê) liên
# (ê) mức đ
# (ô) tô
# (ố) đồn
# (c) tổ
# (n) sao ch
# (c) comit
# (c) lệnh // lện
# (ế) thương mạ
# (ế) (thuộc) t
# (ế) tiền hoa
# (ế) hàng hoá
#
# (ê) phươn
# (c) thông tin,
# (ố) hoá
# (ố) sự
# (ố) hoá
# (ô) co
# (ô) sự
# (ô) tí
# (ô) co
# (ế) hãng, côn
# (ế) chạy đua,
# (t)
#
# (c) tính đ
# (c) mớ; đ
# (ố) sự
# (í) sự
# (c) tí
# (h)
#
# (í) hai
# (í) tập
# (ề)
# (c) kh
# (c) có khả
# (a) (x +y ) = b
# (c) đồng
# (c) kết lu
# (c) kết lu
# (n);
# (í) tín
# (í) vật
# (ô) đố
# (c) cấu h
# (c) cấ
# (ị); (thống kê) tín
# (ê) tính
# (ê) trùng
# (ê) đã tr
# (ê) chất
# (ô) sự
# (ố) đồn
# (c) cô
# (n)
#
# (c) phép h
# (c) hệ quả
# (í) bảo
# (ế) gửi đi (h
# (ê) tính
# (t) dẫm c
# (n) chòm s
# (c) sự xây
# (c) xây dự
# (c) súc tí
# (ô) sự
# (ê) sự ng
# (ế) hợp đồng
#
# (ô) co
# (c) sự phủ
# (c) sự phủ
# (c) mâu th
# (c) lập tr
# (c) trái l
# (c) vô hiệ
# (ế) thuế
#
# (h) máy b
# (ê) dụng
# (c) hệ
# (c); điểm góc (của
# (ế) nghiệp đo
# (í) hạt
# (c) hạ
# (a),
# (i),
# (ê) sự tư
# (ê) tương
# (ô)
#
# (c) vũ
# (n) tinh n
# (n) vũ trụ
# (n) vũ trụ
# (n) vũ trụ
# (ế) chi phí,
# (.), cách hai,
# (i) quân cờ nhảy ||
# (ê) hiệp
# (ê) phủ;
# (c) làm
# (h) cracôv
# (ê) tin đ
# (ê) tín d
# (ê) người
# (c) rão
# (n) trăng
# (c) đỉn
# (ế) khủng hoả
# (ô) mũ
# (ô) th
# (ô) th
# (g); đi
# (c) cu
# (a)
# (ô) tí
# (ơ)
#
# (h)
#
# (c) điểm
# (c) đi
# (c) mặ
# (í) làm
# (h) bảng
# (h) số li
# (ế) sức bán,
# (ế) món nợ
#
# (ê) người
# (c) hì
# (c) th
# (h)
#
# (í) phâ
# (í) giả
# (h); 1
# (ê) đọc m
# (i) cỗ bài
#
# (n) nghiên
# (c) suy di
# (c) suy di
# (c) suy di
# (ố)
# (c) tính x
# (c) biểu t
# (c) định n
# (n)
#
# (g); (bị) khúc xạ
#
# (í) sự
# (;), toá
# (h) tính s
# (h) (phươn
# (h) sự ph
# (;)
#
# (n) nửa th
# (ê) khoa
# (c) mư
# (i) mặt nhị, mặt ch
# (ô) hì
# (ô) câ
# (c) sự phủ
# (ế) sự định g
# (ế) gửi tiền
# (ế) hạ, giảm
# (ế) sự suy th
# (h) đạo số
# (c) suy ra
# (h)
#
# (c) sự mô
# (c) mô tả
#
# (c) sự chỉ
# (h) bàn;
# (h) chỗ g
# (í) phá
# (í) sự
# (ố) địn
# (i) quân nhị
#
# (í) xuấ
# (h) thứ t
# (ê) sự lệ
# (h) thiết
# (h) chuẩn
# (y)
#
# (h) chuẩn
# (h) biểu
# (c) sơ
# ( )
#
# (c) (thuộc
# (c) nhà bi
# (í) ngh
# (í) tín
# (c) đường
# (c) đư
# (c) đư
# (i) quân vuông (car
# (i) thẻ đánh bài, t
# (i) quân (hạt) súc
# (ô) lư
# (ô) tí
# (h) đọc đ
# (í) (ch
# (í) nhi
# (í) sự
# (c) ống
# (c) số
# (ô) lư
# (ố) phé
# (c) lưỡng
# (g)
#
# (c) ch
# (ố) hạn
# (h) điôt
#
# (í) khú
# (i) chui (bài)
#
# (t) cắt,
# (ế) [sự, cố]
# (g)
#
# (u)
#
# (c) phép t
# (n)
#
# (ể)
#
# (ê) sự ph
# (h) bộ ph
# (ê) sự ph
# (g)
#
# (h) bộ ph
# (ố) son
# (c) sự
# (h) bộ ch
# (h) bộ ch
# (ê) liều
# (.)
#
# (h) đôi,
# (h) bộ nh
# (h) nhị t
# (c) xuô
# (i) trò chơi cờ đam
# (i) kéo, rút (bài);
# (ê) sự lấ
# (c) điề
# (ế) sự giảm t
# (í) ống
# (c) dẻo
# (h) dụng
# (c) độ
# (n)
#
# (n) sự che
# (n) (đường
# (ê) kinh
# (c) ki
# (í) xoá
# (ố) khử
# (ê) hiệu
# (ê) hữu h
# (n)
#
# (8
# (8)
# (0)
# (ố) đơn
# (ố) một
# (í) ném
# (h) sự né
# (t) [bơm,
# (í) (th
# (c) đi
# (1)
# (c) tính k
# (ô) sự
# (ệ), sự
# (ố) tự
# (ê) nội s
# (í) thu
# (ế) niên bổng
# (h) kích
# (i) sự ra nhập; (má
# (p) t
# (;)
#
# (ố) có
# (u)
#
# (c) ph
# (n) phân đ
# (ơ)
#
# (h) xoá k
# (ê) ước l
# (;)
#
# (í) sự
# (t) ; (th
# (n)
#
# (a)
# (ố) dư,
# (ô) sự
# (í) sự
# (í) kíc
# (g) dịch
#
# (í) toả
# (t) độ ch
# (í); (t
# (ê) kỳ vọ
# (ê) kỳ vọ
# (ê) sự ti
# (ê) tiêu
# (c) phần
# ( )
#
# (ế) sự lợi dụ
# (c)
#
# (c) số
# (ế) xuất cảng
# (ế) sự xuất c
# (í) sự
# (c)
#
# (c) mở rộn
# (c) giãn
# (ế) sự thanh
# (ế) sự thanh
# (n)
# (n)
#
# (g) cự
# (í) thị
# (h) nhân
# (ử), tính nhân
# (ử)
#
# (ử)
#
# (ử)
#
# (h) chế t
# (í) sự
# (í) fad
# (ế) phá sản
#
# (h) chỗ h
# (c) sai
#
# (c) sự sai
# (í) sự
# (h) sự sa
# (h) sự cấ
# (c) sự liên hệ
# (h) bộ ph
# (h) sự cấ
# (h) cảm t
# (h) ferit
# (í) chấ
# (ô) th
# (h) độ tr
# (5)
# (0)
# (ố); hệ số;
# (h) bộ ph
# (ố) băn
# (h); (vật
# (h) sự ch
# (c); (vật lí) c
# (c) bộ
# (ế) tài chính
# (ế) (thuộc) t
# (h) bộ tì
# (ô) mị
# (c) tín
# (ô) mị
# (c) chủ ng
# (ế) hàng buôn
# (ế) (thuộc) t
# (i) thẻ bằng ngà
#
# (í) sự
# (5
# (ô) sự
# (í) ngọ
# (c) cán
# (í) tia
# (h) thiết
# (c) sự
# (h) dấy p
# (í) phá
# (c) ti
# (h) bộ nh
# (c); phút (đơn v
# (c) chủ ng
# (c) hình t
# (0)
# (4
# (ố) nhó
# (ổ) (8
# (4)
# (ê) điểm
# (c) ph
# (í) tần
# (í) ma
# (í) tuy
# (c) tu
# (c) điể
# (ô) qu
# (c) hà
# (ế) quỹ
#
# (c) dâ
# (t) kíp n
# (í) sự
# (c)
#
# (i) sự được cuộc
#
# (n) (thuộc
# (í) (th
# (i) (cờ) bạc
#
# (i) người đánh bạc
#
# (;)
#
# (í) khí
# (í) thể
# (h) sơ đồ
# (h) được
# (h) sự ch
# (í) độ
# (c) Ga
# (u) tru
# (c) [phần
# (i); hh(đại s
# (c) di
# (c) đị
# (c) hì
# (c) vậ
# (ô) mầ
# (c) qu
# (c) phép
# (u)
#
# (c) [bộ, cái] đ
# (c)
#
# (ố) phâ
# (ố) phâ
# (g);
#
# (ố) bị
# (c); (vật
# (ố) sự
# (í) hạt
# (c) Gr
# (í) (th
# (í) làm
# (í) hạt
# (h) dụng
# (c) đồ
# (t) mạng,
# (í) bị
# (í) sự
# (í) (th
# (ố) phỏ
# (ế) người bảo
# (h) bảo v
# (c) điều khiển
# (í) ống
# (c) co
# (h) máy l
# (ố) nửa
# (ê) bán b
# (ố) nửa
# (h) chia
# (i) người chơi; (má
# (h) điều
# (í) độ
# (x)/2 =
# (i) trò chơi đen đỏ
# (í) sự
# (í) nhi
# (í) dụn
# (n) bầu tr
# (c) mặ
# (ô) nử
# (ố) nửa
# (c) (thuộ
# (c) hì
# (ê) có ph
# (ê) khác
# (c) hì
# (u)
#
# (c) kh
# (ố) (nh
# (c) tính
# (ê) tính
# (c) đơn ứ
# (ố) đồn
# (c) phép
# (ố) đồn
# (ố) tín
# (i)
#
# (n) đường
# (c) đư
# (í) nón
# (ô) ba
# (0)
#
# (c) th
# (í) thu
# (c) siêu
# (ố) siê
# (h) s
# (h) siêu e
# (ố) siê
# (ố) siê
# (h) siêu đ
# (ố) siê
# (ố) siê
# (ố) siê
# (i)
#
# (ố) siê
# (c) xây dự
# (c) giả th
# (í) hiệ
# (c) kh
# (c) khái n
# (ố) iđê
# (í) nhâ
# (ê) khả n
# (c) sự nhận ra;
# (í) bốc
# (c) sự khô
# (í) /tí
# (í) [tí
# (ạ)
#
# (c) nhúng
# (c) sự nh
# (ê) sự di
# (í) trở
# (c) kéo th
# (c) phép t
# (á)
#
# (c) sự man
# (ố) phi
# (h); (vật
# (h) bộ th
# (c) độ ng
# (í) khô
# (ế) thu nhập
#
# (c) tính k
# (c) không
# (c) không
# (ê) sự ph
# (ê) mắc n
# (c) tính k
# (c) không
# (c) tính độc lậ
# (í) chỉ
# (c) ch
# (í) [tí
# (c) phép q
# (c) cô
# (í) khô
# (c) qu
# (ê) không
# (c) suy lu
# (c) (thuộc
# (í) tia
# (c) thông tin,
# (h) van v
# (ế) nhu cầu
#
# (h) đưa (
# (h) sự đư
# (ế) [tình trạ
# (c) hình
# (c) [sự, tính]
# (ế) trả tiền
# (í) các
# (í) cái
# (ế) sự bảo hi
# (h) máy đ
# (h) phép l
# (h) máy l
# (c) nội hà
# (h) tính
# (h) sự nố
# (h) biến
# (ê) tương
# (c) suy lẫ
# (ế) lãi
#
# (í) mặt
# (í) gia
# (í) cái
# (h) cấm /
# (í) biế
# (h) máy n
# (c) giải t
# (g) gi
# (n) giữa c
# (ê) trong
# (ê) trong
# (c) không
# (c) trực g
# (c) (thuộc
# (c) chủ ng
# (c) ch
# (ê) kiểm
# (p
# (c) bộ phận biể
# (ế) hùn (vốn)
# (ế) vốn đầu t
# (ế) người hùn
# (ế) giấy biên
# (í) iôn
# (í) (th
# (í) sự
# (ố) tín
# (c) không
# (í) đẳn
# (í) đườ
# (c) đư
# (í) đẳn
# (ố) phé
# (ố) đẳn
# (í) có
# (h) máy g
# (ố) cô
# (ố) cái
# (í) đồn
# (ố) đơn
# (g)
#
# (í) đẳn
# (c) đẳ
# (ô) hợ
# (ô) eo
# (t) vít n
# (c) Ja
# (í) tia
# (i) quân phăng teo
#
# (t) ngõng
# (h) sự ch
# (c) ghép,
# (c); tiế
# (í) kên
# (í) hạc
# (h) út bấ
# (c) độ
# (h) bộ dụ
# (i) tiền thua cuộc
#
# (í) kli
# (h) cái n
# (ô) nú
# (ế) độ nhọn
#
# (ế) lao động,
# (c) (thuộc) mê
# (;)
#
# (ê) biểu
# (n) vĩ độ,
# (ố) dàn
# (c)
#
# (c) trô
# (c) hệ
# (í) thấ
# (ê) độ nh
# (ế) thu thuế
#
# (u) t
# (ê) phải
#
# (n) bình đ
# (í) thờ
# (ê) hợp l
# (ự)
# (h) tuyến
# (í) số
# (í) sự
# (í) hoá
# (c) Lô
# (h) địa p
# (h) mắt (
# (c) tốc đồ
#
# (c) lô
# (h) lôg
# (c) lôgic
# (ê) lôgit
# (c) xà
# (c) vỏ
# (í) són
# (u)
#
# (ê) sổ số
# (í) âm
# (c) đường
# (c). đ
# (í) tín
# (í) thi
# (í) sự
# (í) phá
# (í) tră
# (n) (lịch)
# (c);
# (ê) thống
# (í) nam
# (í) từ
# (í) thu
# (í) từ
# (í) sự
# (í) sự
# (í) sự
# (h) macni
# (n) độ lớn
# (t) sự đó
# (í) tín
# (c) đa tạ
# (h) cái k
# (c) Má
# (t) macti
# (i) đối thủ ngang s
# (c) chủ ng
# (c) (thuộc
# (c) to
# (h) sơ đồ
# (í) vật
# (ế) trả tiền
# (ế) thời gian
# (ê) loại
# (i) maximin
#
# (t) dụng
# (c) có
# (c) trung
# (u)
#
# (í) nón
# (p)
#
# (í) màn
# (c) mặt k
# (c) tí
# (ế) hàng hoá;
# (ế) nhà buôn
#
# (ế) sự hợp lạ
# (c) ph
# (ố) phé
# (i);
# (ê) có độ
# (ố) mêt
# (ố) mêt
# (í) kim
# (c) mêta n
# (í) (th
# (c) mêta l
# (c) (thuộc
# (c) mêta t
# (ê) độ đo
# (c) mêta h
# (c) mêta l
# (n) sao bă
# (n) thiên
# (h) dụng
# (c) đưa và
# (c) (thuộc
# (t) thước
# (í) (cá
# (h) vi ch
# (h) rơle
# (í) kín
# (ê) thống
# (c)
#
# (ê) nửa t
# (c) hệ quả
# ( )
#
# ( )
#
# (c) Mi
# (ố) địn
# (h) tính
# (h) tính
# (c) sự không ph
# (h) sự là
# (h) tầng
# (ô) nử
# (c) (thuộc
# (c) mốt, t
# (y) đ
# (g);
# (c) mô
# (í)biến
# (í)bị b
# (í) sự
# (í) máy
# (ố) môđ
# (o) m
# (c) ph
# (í) phâ
# (í) (th
# (í) độn
# (ế) tiền, tổn
# (h) mônit
# (í) đơn
# (ô) đơ
# (c) mo
# (ố) phé
# (n) tháng
#
# (n) mặt tr
# (ố) cấu
# (ê) cầm đ
# (ô) mo
# (í) chu
# (í) độn
# (h) lắp r
# (c) tính
# (ế) động sản
#
# (i) nước đi (bài)
#
# (ê) trượt
# (à
# (h) nhiều
# (h) nhiều
# (ê) đa cộ
# (ố) vi
# (ô) đa
# (ố) đa
# (ố) đa
# (t) nhiều
# (ê) nhiều
# (c) nhiều
# (h) thiết
# (í) cực
# (h) vạn n
# (h) bộ đế
# (h) nhiều
# (c) đa vé
# (h) máy đ
# (h) nhiều
# (ê) kiểm
# (n) thiên
# (c) tự
# (n) tinh v
# (c) phủ đị
# (c) sự phủ
# (í) bản
# (ì)
#
# (h) sơ đồ
# (h) cái tr
# (c) Nu
# (ố) luỹ
# (ố) rađ
# (ố) chu
# (9
# (9)
# (c) nú
# (m)
# (m)
# (ế) quy định
# (c) to
# (ê) phần
# (c) sự khô
# (h),
# (h) thang
# (ô) kh
# (c) không
# (c) không
# (ế) tín phiếu
# (c) khái n
# (n) sao mớ
# (;)
#
# (í) (th
# (h) hàm là
# (ố) số
# (g) s
# (g) s
# (h) dụng
# (c) chư
# (h) hoàn
# (ể),
# (n) độ ngh
# (ê) sự qu
# (c) qu
# (c) sự
# (c)
#
# (i) mặt ngửa
#
# (t) sự ch
# (t) sự xu
# (c) hì
# (í) bát
# (h);
# (í) thị
# (t) (thuộ
# (;)
#
# (c) tính Ω
# (h) một đ
# (c) một ch
# (h) đóng
# (c) (thuộc
# (í) [tí
# (í) chắ
# (h) ôpêra
# (t) sử dụ
# (c) sự làm việc
# (c) to
# (h) opêra
# (i) đối phương
#
# (í) (th
# (í) qua
# (c) mặt c
# (c) qu
# (h) lệnh
# (ê) thống
# (c) kiểu t
# (ô) tí
# (ô) đư
# (n) gố
# (ố) phầ
# (ố) phé
# (ự)
# (í) cái
# (í) biể
# (c) mật t
# (c) sự mậ
# (c) mật t
# (h) thiết
# (h) van r
# (ế) tiền phí
# (ế) tiền chi
# (h) lối r
# (ê) giá t
# (h) lối r
# (ế) chưa trả
# (h) tính h
# (c) điều chỉnh
# (h) sự xác
# (ố) trư
# (h) dòng
# (ế) tạp phí
#
# (ê) sự xá
# (n)
# (í) sự
# (ố) vàn
# (ế) mắc nợ; c
# (i) cỗ bài
#
# (h) khối
#
# (ô) ph
# (h) panen
# (h) mãy v
# (o)
#
# (h) para-g
# (c) pa
# (c) pa
# (ô) pa
# (c) (thuộc
# (i)
#
# (n) thị sa
# (c) sự suy
# (í) thu
# (c) th
# (h) parame
# (c) có tính chấ
# (c) để tro
# (i) người cùng phe
#
# (ê) không
# (c) (thuộc
# (c) bệnh l
# (i)
# (n)
#
# (c) sư
# (c) co
# (í) con
# (í) sự
# (c) kh
# (h) pentố
# (n) vùng n
# (ê) phân
# (n) điểm c
# (n) điểm c
# (n) điểm c
# (h) tuần h
# (ê) chu k
# (ố) sự
# (ế) quyền sở
# (c) phép
# (h) (thuộc
# (;)
#
# (h) đầu đ
# (í) pin
# (i) số (trên quân b
# (t) pittô
# (c) lõ
# (n) hành t
# (c) hà
# (h) máy t
# (c) đo
# (í) pla
# (í) tín
# (ê) có độ
# (i) trò chơi, cuộc
# (i) người chơi, đấu
# (ế) cầm cố
#
# (i) kế hoạch chơi
#
# (h) dụng
# (h) cái v
# (h) cái p
# (h) cái đ
# (h) đa điề
# (h) đa điề
# (h) cho đ
# (i)
# (h) được l
# (c) đườ
# (c) đa cô
# (c) đa
# (h) đa điề
# (c) hì
# (i) đ
# (h) đa lôg
# (í) nhi
# (í) đa
# (i) số tiền đặt cọc
# (í) tín
# (c) vị
# (h) đặt v
# (í) pôz
# (ế) tài sản;
# (p)
#
# (c) sự giả
# (c) dựa và
# (h)
#
# (n) sự tiế
# (h) chiều
# (c) khả vị
# (c) vị từ
#
# (c) thiết bị dự
# (i)
#
# (t)
#
# (í) áp
# (ế) giá cả, g
# (h) in
#
# (c) hì
# (c) lă
# (c) xá
# (c) th
# (ê) biện
# (p) c
# (ế) tài sản;
# (c) tỷ
# (c) mệnh đ
# (c) (thuộc
# (h) thiết
# (c) chứng
# (c) chứng
# (c) gi
# (ô) gi
# (h) giả ch
# (h) giả l
# (h) giả tu
# (c) giả câ
# (ố) giả
# (c) giả v
# (;)
#
# (h) hàm ps
# (c) tâ
# (í) tấn
# (í) mạc
# (í) sự
# (h) máy p
# (h) máy đ
# (h) bị đụ
# (h) máy đ
# (ế) mua
#
# (m)
#
# (c) hì
# (c) Pi
# (c) tứ
# (c) gố
# (ê) chọn
# (í) mạn
# (ố) dạn
# (c) lượng
# (c) phép l
# (í) sự
# (ê) điểm
# (h) tựa gi
# (h) tính t
# (ố) tựa
# (ố) tựa
# (c) tựa cú
# (h),
# (c) ti
# (í) bức
# (í) sự
# (c) đẳng
# (í) rađ
# (í) tín
# (m); tk; cỡ mẫu c
# (a)
#
# (ê) khoản
# (i), tỷ số
# (h) máy đ
# (í) trở
# (í) lò
# (h) sự đọ
# (ế) bất động
#
# (ế) hạ giá
#
# (ế) giấy biên
# (c) máy thu
#
# (í) sự
# (h) sự gh
# (h) sự đo
# (h) máy g
# (c) sự phục hồi
# (c) hì
# (h) máy c
# (c) tính đ
# (h) chu t
# (ế) chuộc; bồ
# (ợ)
# (í) cái
# (i) trọng tài
#
# (ố) sự
# (c)
#
# (í) gươ
# (í) khú
# (í) sự
# (í) khú
# (í) hiệ
# (í) kín
# (ế) trả (tiền
# (c) bác bỏ
# (c) sự bác
# (c) bác bỏ
# (í) sự
# (h) cái g
# (ê) biến
# (ê) hồi q
# (ê) biến
# (c) cái điều ch
# (c) nửa q
# (í) tươ
# (í) sự
# (h) rơle
# (í) từ
# (ừ)
#
# (ê) tiền
# (ê) tô
#
# (ế) sự bồi th
# (ợ)
# (h) bộ lặ
# (n)
#
# (c) tính t
# (ê) sự lặ
# (p) b
# (h) lapạ
# (í) sự
# (í) đẩy
# (ế) mua lại
#
# (h) sự gh
# (í) năn
# (í) điệ
# (h) (cái)
# (h) thiết
# (í) sự
# (í) cộn
# (í) cái
# (ế) phần còn
# (ế) sự bồi th
# (ố) kết
# (ô) co
# (c) điều chỉnh
# (n) chuyển
# (ế) làm lưu t
# (ế) thu nhập
# (í) sự
# (n) chuyển
# (í) cái
# (;)
#
# (
# (
# (c) cạn
# (ố) vàn
# (ố) phỏ
# (h) loại
# (ê) độ mạ
# (c) tự động hoá
# (ô) có
# (h) khai
# (i) rulet
#
# (h) sự lấ
# (h) chươn
# (ệ)
#
# (c) hình
# (t) độ võ
# (ế) tiền lươn
# (ế) sự bán (h
# (ê) mẫu
#
# (c) người lấy m
# (ê) sự lấ
# (n) sarốt
# (c) tính t
# (h) máy đ
# (h) nhìn,
# (h) đơn di
# (h) tựa đơ
# (c) dừn
# (i) sự đếm điểm; (t
# (t) nép c
# (ô) ch
# (c) sự tìm
#
# (n)
#
# (c) ti
# (n)
#
# (h) máy c
# (h) selec
# (c) tự trị, độc
# (c) tự sửa
#
# (c) sự tự kích
# (h) tự lậ
# (c) tự điều chỉ
# (c) sự tự tái s
# (ế) bán, thươ
# (ế) sự bán (h
# (c) (thuộc
# (c) ngữ ng
# (c) nửa t
# (í) chấ
# (ế) bán bất b
# (h) nửa qu
# (c) ký hiệ
# (ố) nửa
# (c) câu, m
# (c) (thuộc
# (ố) cái
# (ố)
#
# (h);
# (c) dã
# (o) c
# (y)
#
# (ố) bắc
# (7
# (7)
# (0)
# (ê) lục p
# (h);
# (c) trụ
# (ế) phần; cổ
# (ô) bó
# (í) màn
# (h) sự rờ
# (h) thiết
# (h) thời
# (í) són
# (ô) co
# (i) trộn bài, trang
# (h) dừng
# (h) dừng
# (i) sáu điểm, mặt l
# (n) vũ trụ
# (;)
#
# (ố) ký
# (c) phép
# (ô) đơ
# (c) đơ
# (h) sự mô
# (h) thiết
# (h) một đ
# (g)
# (0)
# (h) con t
# (h) nhát c
# (h) chậm
#
# (ế) xuống giá
# (n) mặt tr
# (i) trò choi một ng
# (n) chí đi
# (ế) khả năng
# (ế) trả tiền,
# (h) thiết
# (í) âm
# (í) sự
# (h) thiết
# (í) âm
# (n) phương
# (c) kh
# (h) xếp đ
# (c) khoản
# (ế) tiền (kim
# (c) ph
# (ế) đầu cơ
#
# (ế) sự đầu cơ
# (c) su
# (g)
#
# (c) hì
# (c) ph
# (í) spi
# (t) trục
#
# (c) điểm
# (i)
#
# (ế) sự kiện c
# (c) tính
# (c) cầu p
# (c) hình
# (h) máy l
# (ê) tổng
# (h) ổn địn
# (g)
#
# (i) tiền đặt cọc
#
# (ô) th
# (h) dụng
# (n) sao, h
# (ê) thống
# (c) th
# (n) (thuộc
# (ố) hầu
# (c) rađia
# (c) (thuộ
# (ế) dự trữ (h
# (h) nhớ
#
# (c) biế
# (c) ch
# (i) chiến lược
#
# (c) phân
# (ê) sự ph
# (c) sự
# (c) ứng
# (h) dòng
#
# (x)/(a-x))
#
# (ố) cấu
# (ố) đại
# (h) bộ ph
# (c) lớp co
# (ô) ph
# (ố) trự
# (c) đường
# (ô) đồ
# (í) sự
# (c) đa tậ
# (h) chươn
# (c) thứ t
# (h) chươn
# (ố) vàn
# (ê) mẫu c
# (c) cái th
# (ô) tầ
# (ố) dàn
# (c) tiếp
# (h) thiết
# (n) cận nh
# (c) số hạn
# (c) lực
# (h) tính k
# (ố) số
# (h) máy c
# (c) tiền đ
# (n) mặt tr
# (ố) siê
# (ô) si
# (í) tín
# (ố) nhó
# (í) sự
# (n) p
# (i)
# (c) xun
# (h) ngắt
# (h) bảng
# (c) tam đo
# (c) ký
# (c) hệ ký
# (c) ký hiệ
# (l)
# (h) bộ tổ
# (ố) hội
# (h) tốc k
# (c) quỹ t
# (c) tacnô
# (c) tiếp
# (c) ch
# (i) mặt trái (đồng
# (c) ti
# (ế) băng giá
#
# (;)
#
# (c) Tô
# (c) đẳng
# (c) (thuộc
# (ế) thuế
#
# (ế) sự đánh t
# (c) kỹ
# (t) liên
# (t) đo lư
# (c) kí
# (í) nhi
# (h) tiến t
# (0)
# (ế) có thời g
# (c) qu
# (c) lưới
# (h) dụng
# (c) tứ
# (c) tứ
# (a) kính
# (c) lý
# (c) nh
# (í) ion
# (í) (th
# (í) nhi
# (í) nhi
# (í) nhi
# (í) hạt
# (;)
#
# (3)
# (0)
# (0)
# (0)
#
# (3
# (c) th
# (~
# (ế) thuế cầu,
# (h)
#
# (í) âm,
# (a) khoa
# (c) tô
# (ô) hì
# (c) mặt k
# (m)
#
# (í) xoắ
# (h) sự lấy
# (h) bộ tổ
# (g)
#
# (n)
#
# (ế) thương mạ
# (h) thiết
# (h) máy b
# (ô) sự
# (t) [máy
# (n) sự qua
# (í) sự
# (c) máy phát
#
# (c) truyền (đạt
# (c) hì
# (t) gia c
# (ê) xu th
# (i) ba điểm
#
# (ô) ta
# (c) ta
# (ô) ta
# (ô) ph
# (h) trigơ
# (c) ta
# (c) lư
# (h);
# (c) độ
# (0)
#
# (c) tr
# (ố) nhi
# (ố) tần
# (i) lá bài ăn, quân
# (c) dàn
# (ế) từ rớt, t
# (c) sun
# (t) thiết
# (t) tuabi
# (0
# (0)
# (t) bước
# (2
# (h) thiết
# (ố) siê
# (ố) siê
# (í) siê
# (í) cực
# (c) đi
# (n) sự che
# (c) tính không
# (ê) không
# (h) mở
#
# (c) tính k
# (c) không
# (ự)
# (h) đa thứ
# (í) chu
# (c) đơn hướng,
# (h) sự đơn
# (h) đơn tr
# (h) đơn tr
# (ê) một p
# (ê) một m
# (ố) đơn
# (ố) đơn
# (h) bộ tì
# (ố) một
# (h) vòng t
# (h) đơn di
# (ô) kh
# (c) không bão h
# (c) tính k
# (ê) sự dư
# (;)
#
# (i)
# (í) Châ
# (ê) sự th
# (ố) đán
# (í) sự
# (ê) [tính
# (ố)
# (ê) phươn
# (ê) biến
# (c) bi
# (h) máy d
# (c) ve
# (e)
#
# ( )=a 3 )
#
# (n) thiên
# (t) tàu,
# (í) sự
# (t) cái d
# (í) (th
# (o)
#
# (c) rô
# (í) tín
# (ế) lương
#
# (c) vết
# (ê) di độ
# (ê) di độ
# (ê) hàng
# (ế) bảo đảm
#
# (c) dạng sóng (
# (t) ống d
# (í) độ
# (ế) (mua; bán
# (c) cán
# (í) côn
# (;)
#
# (;)
#
# (n) hoàng
# (í) (th
# (c) đớ
